# %% [markdown]
# # Setup
#
# This is following [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) for Pandas (v 2.x.x, as of this writing) but may take a little more than 10 minutes to finish. Lot's of small changes, references etc. The original notebook was downloaded from
# [this repo on github](https://github.com/shauryashaurya/learn-data-munging/blob/main/02-Pandas/01.01-10%2B-minutes-to-Pandas.ipynb).

# %% [markdown]
# You can also open this notebook in Google Colab
#
# <a href="https://colab.research.google.com/github/shauryashaurya/learn-data-munging/blob/main/02-Pandas/01.01-10%2B-minutes-to-Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.26.0'

# %%
pd.__version__
# Out:
# '2.1.2'

# %% [markdown]
# # Object creation

# %%
# Series - pass a list to pd.Series
s1 = pd.Series([1, 2, 3, np.nan, 5])

# %%
s1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# dtype: float64

# %%
# create an index to use in the dataframe
# default frequency is D (day), so creates a DatetimeIndex of 10 days
dates = pd.date_range("20220619", periods=10)
dates
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# just in case you are wondering, here's [all the "offset aliases"](https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases) for Datetime

# %%
# Dataframe - pass a Numpy array
# create a 10 row, 4 col random number array, index by dates, give some column names
df = pd.DataFrame(np.random.randn(10, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320
# 2022-06-23 -0.511189 -0.610947 -0.234703 -0.108703
# 2022-06-24 -0.728290  1.231819  0.430074  0.947210
# 2022-06-25 -0.444771 -0.832265  1.604595  0.279618
# 2022-06-26  0.378996 -0.507757  0.439415  1.480208
# 2022-06-27  0.000805 -0.164564 -0.033391  0.851357
# 2022-06-28 -0.679106  1.201701  0.100458 -0.301494

# %%
# Create a dataframe by passing a dictionary of objects
# where each object can be converted into a series-like structure
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20220619"),
        "C": pd.Series(1, index=list(range(6)), dtype="float32"),
        "D": np.array([3] * 6, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train", "test", "train"]),
        "F": list("foofoo"),
        "G": "foo",
    }
)

df2
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %%
# the datatype of each of the columns would be different
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# G           object
# dtype: object

# %% [markdown]
# # Viewing Data

# %%
# top of the dataframe
df.head()
# Out:
#                    A         B         C         D
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320
# 2022-06-23 -0.511189 -0.610947 -0.234703 -0.108703

# %%
# bottom 3 records of the dataframe
df.tail(3)
# Out:
#                    A         B         C         D
# 2022-06-26  0.378996 -0.507757  0.439415  1.480208
# 2022-06-27  0.000805 -0.164564 -0.033391  0.851357
# 2022-06-28 -0.679106  1.201701  0.100458 -0.301494

# %%
# index of the df
df.index
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
# columns of the df
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# .to_numpy gives a NumPy representation of the dataframe
# this is expensive if all columns are of different data type
# NumPy arrays support a single data type
# so with mixed data types, the data type of
# each element is
df.to_numpy()
# Out:
# array([[-1.54968476e+00, -4.48156065e-01, -9.67573102e-01,
#         -1.55685222e+00],
#        [ 1.14004175e+00,  5.94596965e-01,  1.23442104e+00,
#         -1.05037271e+00],
#        [-1.33403417e+00, -2.42770872e+00,  6.48506786e-01,
#         -9.95819184e-01],
#        [-3.93233317e-01,  1.34498437e+00, -1.10085862e-01,
#         -3.41320347e-01],
#        [-5.11189455e-01, -6.10946766e-01, -2.34703303e-01,
#         -1.08703223e-01],
#        [-7.28289786e-01,  1.23181875e+00,  4.30073844e-01,
#          9.47210111e-01],
#        [-4.44770819e-01, -8.32264943e-01,  1.60459520e+00,
#          2.79617547e-01],
#        [ 3.78996170e-01, -5.07756663e-01,  4.39415213e-01,
#          1.48020785e+00],
#        [ 8.05009872e-04, -1.64564085e-01, -3.33911790e-02,
#          8.51357037e-01],
#        [-6.79105932e-01,  1.20170122e+00,  1.00458012e-01,
#         -3.01493735e-01]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo']], dtype=object)

# %%
# quick summary stats
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.412047  -0.061830   0.311172  -0.079617
# std     0.784010   1.179981   0.741130   0.975578
# min    -1.549685  -2.427709  -0.967573  -1.556852
# 25%    -0.715994  -0.585149  -0.090912  -0.832194
# 50%    -0.477980  -0.306360   0.265266  -0.205098
# 75%    -0.097705   1.049925   0.596234   0.708422
# max     1.140042   1.344984   1.604595   1.480208

# %% [markdown]
# 1. **count** = Count number of non-NA/null observations
# 1. **max** = Maximum of the values in the object
# 1. **min** = Minimum of the values in the object
# 1. **mean** = Mean of the values
# 1. **std** = Standard deviation of the observations
# 1. **25%** = Default lower percentile
# 1. **50%** = 50 percentile - same as the median
# 1. **75%** = Default upper percentile

# %%
# change the percentiles
df.describe(percentiles=[0.1, 0.5, 0.9])
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.412047  -0.061830   0.311172  -0.079617
# std     0.784010   1.179981   0.741130   0.975578
# min    -1.549685  -2.427709  -0.967573  -1.556852
# 10%    -1.355599  -0.991809  -0.307990  -1.101021
# 50%    -0.477980  -0.306360   0.265266  -0.205098
# 90%     0.455101   1.243135   1.271438   1.000510
# max     1.140042   1.344984   1.604595   1.480208

# %%
# E, F, G in d2 are not numeric, so do not come up in describe()
df2.describe()
# Out:
#          A                    B    C    D
# count  6.0                    6  6.0  6.0
# mean   1.0  2022-06-19 00:00:00  1.0  3.0
# min    1.0  2022-06-19 00:00:00  1.0  3.0
# 25%    1.0  2022-06-19 00:00:00  1.0  3.0
# 50%    1.0  2022-06-19 00:00:00  1.0  3.0
# 75%    1.0  2022-06-19 00:00:00  1.0  3.0
# max    1.0  2022-06-19 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
# transpose the data
# turn rows to columns and vice versa
df.T
# Out:
#    2022-06-19  2022-06-20  2022-06-21  2022-06-22  2022-06-23  2022-06-24  \
# A   -1.549685    1.140042   -1.334034   -0.393233   -0.511189   -0.728290
# B   -0.448156    0.594597   -2.427709    1.344984   -0.610947    1.231819
# C   -0.967573    1.234421    0.648507   -0.110086   -0.234703    0.430074
# D   -1.556852   -1.050373   -0.995819   -0.341320   -0.108703    0.947210
#
#    2022-06-25  2022-06-26  2022-06-27  2022-06-28
# A   -0.444771    0.378996    0.000805   -0.679106
# B   -0.832265   -0.507757   -0.164564    1.201701
# C    1.604595    0.439415   -0.033391    0.100458
# D    0.279618    1.480208    0.851357   -0.301494

# %% [markdown]
# ### [Axis in pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_axis.html?highlight=set_ax#pandas.DataFrame.set_axis)
#
# ```axis{0 or ‘index’, 1 or ‘columns’}```
#
# Always remember that when you specify:
# * ```axis=0``` or ```axis='index'``` you indicate that the operation should be along the _index_ (aka across the rows). More often than not indexes will go from top to bottom (vertically), but sometimes they may not (for e.g. if you use columns as index or when you have hierarchical or multi-index data).
# * ```axis=1``` or ```axis='columns'``` indicates the operation is along the columns
#
# When in doubt use the explicit version ```'index'``` or ```'columns'``` instead of ```0``` or ```1```

# %%
# sort along the axis - 1 = horizontal
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2022-06-19 -1.556852 -0.967573 -0.448156 -1.549685
# 2022-06-20 -1.050373  1.234421  0.594597  1.140042
# 2022-06-21 -0.995819  0.648507 -2.427709 -1.334034
# 2022-06-22 -0.341320 -0.110086  1.344984 -0.393233
# 2022-06-23 -0.108703 -0.234703 -0.610947 -0.511189
# 2022-06-24  0.947210  0.430074  1.231819 -0.728290
# 2022-06-25  0.279618  1.604595 -0.832265 -0.444771
# 2022-06-26  1.480208  0.439415 -0.507757  0.378996
# 2022-06-27  0.851357 -0.033391 -0.164564  0.000805
# 2022-06-28 -0.301494  0.100458  1.201701 -0.679106

# %%
# sort along the axis - 0 = vertical
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2022-06-28 -0.679106  1.201701  0.100458 -0.301494
# 2022-06-27  0.000805 -0.164564 -0.033391  0.851357
# 2022-06-26  0.378996 -0.507757  0.439415  1.480208
# 2022-06-25 -0.444771 -0.832265  1.604595  0.279618
# 2022-06-24 -0.728290  1.231819  0.430074  0.947210
# 2022-06-23 -0.511189 -0.610947 -0.234703 -0.108703
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852

# %%
# sort ascending by values in a column
df.sort_values(by="A")
# Out:
#                    A         B         C         D
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819
# 2022-06-24 -0.728290  1.231819  0.430074  0.947210
# 2022-06-28 -0.679106  1.201701  0.100458 -0.301494
# 2022-06-23 -0.511189 -0.610947 -0.234703 -0.108703
# 2022-06-25 -0.444771 -0.832265  1.604595  0.279618
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320
# 2022-06-27  0.000805 -0.164564 -0.033391  0.851357
# 2022-06-26  0.378996 -0.507757  0.439415  1.480208
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373

# %%
# sort by non-numerical values
df2.sort_values(by="F", ascending=False)
# Out:
#      A          B    C  D      E  F    G
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo

# %%
# sort by two or more columns
df2.sort_values(by=["F", "E"])
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %% [markdown]
# # Selection

# %% [markdown]
# For production prefer the following instead of other data access methods (typical python methods like ["col"] or [a:b] slices etc.):
#
# ```.at, .iat, .loc and .iloc.```

# %% [markdown]
# ## Getting

# %%
# selecting a single column returns a Series object
df["A"]
# Out:
# 2022-06-19   -1.549685
# 2022-06-20    1.140042
# 2022-06-21   -1.334034
# 2022-06-22   -0.393233
# 2022-06-23   -0.511189
# 2022-06-24   -0.728290
# 2022-06-25   -0.444771
# 2022-06-26    0.378996
# 2022-06-27    0.000805
# 2022-06-28   -0.679106
# Freq: D, Name: A, dtype: float64

# %%
# selecting a slice
df[1:5]
# Out:
#                    A         B         C         D
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320
# 2022-06-23 -0.511189 -0.610947 -0.234703 -0.108703

# %% [markdown]
# ## Selection by label

# %%
# selecting based on a label
df.loc[dates[0]]
# Out:
# A   -1.549685
# B   -0.448156
# C   -0.967573
# D   -1.556852
# Name: 2022-06-19 00:00:00, dtype: float64

# %%
# select on a multi-axis by lable
# I honestly do not know what the comment above means...help!
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2022-06-19 -1.549685 -0.448156
# 2022-06-20  1.140042  0.594597
# 2022-06-21 -1.334034 -2.427709
# 2022-06-22 -0.393233  1.344984
# 2022-06-23 -0.511189 -0.610947
# 2022-06-24 -0.728290  1.231819
# 2022-06-25 -0.444771 -0.832265
# 2022-06-26  0.378996 -0.507757
# 2022-06-27  0.000805 -0.164564
# 2022-06-28 -0.679106  1.201701

# %%
# specific index value results in reduction of dimensions
res = df.loc["2022-06-20"]
print(res)
print("res.shape = ", res.shape, " vs. df.shape = ", df.shape)
# Out:
# A    1.140042
# B    0.594597
# C    1.234421
# D   -1.050373
# Name: 2022-06-20 00:00:00, dtype: float64
# res.shape =  (4,)  vs. df.shape =  (10, 4)

# %%
# get to a specific scalar:
#
# method one
df.loc[dates[0], "A"]
# Out:
# -1.5496847600166925

# %%
#
# method two (slightly faster than method one)
df.at[dates[0], "A"]
# Out:
# -1.5496847600166925

# %% [markdown]
# ## Selection by position

# %%
df.iloc[2]
# Out:
# A   -1.334034
# B   -2.427709
# C    0.648507
# D   -0.995819
# Name: 2022-06-21 00:00:00, dtype: float64

# %%
# slices - similar to NumPy / Python - [row:slice, col:slice]
df.iloc[1:5, 0:2]
# Out:
#                    A         B
# 2022-06-20  1.140042  0.594597
# 2022-06-21 -1.334034 -2.427709
# 2022-06-22 -0.393233  1.344984
# 2022-06-23 -0.511189 -0.610947

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
df.iloc[[0, 1, 2, 6], [0, 2]]
# Out:
#                    A         C
# 2022-06-19 -1.549685 -0.967573
# 2022-06-20  1.140042  1.234421
# 2022-06-21 -1.334034  0.648507
# 2022-06-25 -0.444771  1.604595

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
# change the order of columns, repeact a column
df.iloc[[0, 1, 2, 6], [2, 1, 0, 2]]
# Out:
#                    C         B         A         C
# 2022-06-19 -0.967573 -0.448156 -1.549685 -0.967573
# 2022-06-20  1.234421  0.594597  1.140042  1.234421
# 2022-06-21  0.648507 -2.427709 -1.334034  0.648507
# 2022-06-25  1.604595 -0.832265 -0.444771  1.604595

# %%
# slice rows explicitly, keep all columns
df.iloc[[1, 2], :]
# Out:
#                    A         B         C         D
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819

# %%
# slice columns, keep all rows
df.iloc[:, [2, 3]]
# Out:
#                    C         D
# 2022-06-19 -0.967573 -1.556852
# 2022-06-20  1.234421 -1.050373
# 2022-06-21  0.648507 -0.995819
# 2022-06-22 -0.110086 -0.341320
# 2022-06-23 -0.234703 -0.108703
# 2022-06-24  0.430074  0.947210
# 2022-06-25  1.604595  0.279618
# 2022-06-26  0.439415  1.480208
# 2022-06-27 -0.033391  0.851357
# 2022-06-28  0.100458 -0.301494

# %%
# everything, because you can
df.iloc[:, :]
# Out:
#                    A         B         C         D
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320
# 2022-06-23 -0.511189 -0.610947 -0.234703 -0.108703
# 2022-06-24 -0.728290  1.231819  0.430074  0.947210
# 2022-06-25 -0.444771 -0.832265  1.604595  0.279618
# 2022-06-26  0.378996 -0.507757  0.439415  1.480208
# 2022-06-27  0.000805 -0.164564 -0.033391  0.851357
# 2022-06-28 -0.679106  1.201701  0.100458 -0.301494

# %%
# get to a scalar (2 methods, just like before)
#
# method one: use iloc
df.iloc[1, 2]
# Out:
# 1.2344210416860366

# %%
#
# method two: use iat
df.iat[1, 2]
# Out:
# 1.2344210416860366

# %% [markdown]
# ## Boolean Indexing

# %%
# use a value found in a single col to get data
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373
# 2022-06-26  0.378996 -0.507757  0.439415  1.480208
# 2022-06-27  0.000805 -0.164564 -0.033391  0.851357

# %%
# boolean across the entire DF - vals that don't match go NaN
df[df > 0]
# Out:
#                    A         B         C         D
# 2022-06-19       NaN       NaN       NaN       NaN
# 2022-06-20  1.140042  0.594597  1.234421       NaN
# 2022-06-21       NaN       NaN  0.648507       NaN
# 2022-06-22       NaN  1.344984       NaN       NaN
# 2022-06-23       NaN       NaN       NaN       NaN
# 2022-06-24       NaN  1.231819  0.430074  0.947210
# 2022-06-25       NaN       NaN  1.604595  0.279618
# 2022-06-26  0.378996       NaN  0.439415  1.480208
# 2022-06-27  0.000805       NaN       NaN  0.851357
# 2022-06-28       NaN  1.201701  0.100458       NaN

# %%
# add another column
df11 = df.copy()
df11["E"] = [
    "one",
    "two",
    "three",
    "four",
    "two",
    "five",
    "one",
    "two",
    "three",
    "four",
]
df11
# Out:
#                    A         B         C         D      E
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852    one
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373    two
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819  three
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320   four
# 2022-06-23 -0.511189 -0.610947 -0.234703 -0.108703    two
# 2022-06-24 -0.728290  1.231819  0.430074  0.947210   five
# 2022-06-25 -0.444771 -0.832265  1.604595  0.279618    one
# 2022-06-26  0.378996 -0.507757  0.439415  1.480208    two
# 2022-06-27  0.000805 -0.164564 -0.033391  0.851357  three
# 2022-06-28 -0.679106  1.201701  0.100458 -0.301494   four

# %%
# the isin() query - basically the in clause
df11[df11["E"].isin(["two", "five"])]
# Out:
#                    A         B         C         D     E
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373   two
# 2022-06-23 -0.511189 -0.610947 -0.234703 -0.108703   two
# 2022-06-24 -0.728290  1.231819  0.430074  0.947210  five
# 2022-06-26  0.378996 -0.507757  0.439415  1.480208   two

# %% [markdown]
# ## Setting values

# %%
# matching indexes auto-aligns values
s1 = pd.Series(range(11, 21), index=pd.date_range("20220619", periods=10))
s1
# Out:
# 2022-06-19    11
# 2022-06-20    12
# 2022-06-21    13
# 2022-06-22    14
# 2022-06-23    15
# 2022-06-24    16
# 2022-06-25    17
# 2022-06-26    18
# 2022-06-27    19
# 2022-06-28    20
# Freq: D, dtype: int64

# %%
df["F"] = s1
df
# Out:
#                    A         B         C         D   F
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852  11
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373  12
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819  13
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320  14
# 2022-06-23 -0.511189 -0.610947 -0.234703 -0.108703  15
# 2022-06-24 -0.728290  1.231819  0.430074  0.947210  16
# 2022-06-25 -0.444771 -0.832265  1.604595  0.279618  17
# 2022-06-26  0.378996 -0.507757  0.439415  1.480208  18
# 2022-06-27  0.000805 -0.164564 -0.033391  0.851357  19
# 2022-06-28 -0.679106  1.201701  0.100458 -0.301494  20

# %%
# setting values by label and position
# first let's make a quick copy
df12 = df.copy()
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852  11
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373  12
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819  13
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320  14
# 2022-06-23 -0.511189 -0.610947 -0.234703 -0.108703  15
# 2022-06-24 -0.728290  1.231819  0.430074  0.947210  16
# 2022-06-25 -0.444771 -0.832265  1.604595  0.279618  17
# 2022-06-26  0.378996 -0.507757  0.439415  1.480208  18
# 2022-06-27  0.000805 -0.164564 -0.033391  0.851357  19
# 2022-06-28 -0.679106  1.201701  0.100458 -0.301494  20

# %%
# set by label
df12.at[dates[0], "A"] = 0
# set by position
df12.iat[0, 1] = 0
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19  0.000000  0.000000 -0.967573 -1.556852  11
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373  12
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819  13
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320  14
# 2022-06-23 -0.511189 -0.610947 -0.234703 -0.108703  15
# 2022-06-24 -0.728290  1.231819  0.430074  0.947210  16
# 2022-06-25 -0.444771 -0.832265  1.604595  0.279618  17
# 2022-06-26  0.378996 -0.507757  0.439415  1.480208  18
# 2022-06-27  0.000805 -0.164564 -0.033391  0.851357  19
# 2022-06-28 -0.679106  1.201701  0.100458 -0.301494  20

# %%
# kinda bigger replacement
df12.loc[:, "D"] = np.array([5] * len(df))
df12
# Out:
#                    A         B         C    D   F
# 2022-06-19  0.000000  0.000000 -0.967573  5.0  11
# 2022-06-20  1.140042  0.594597  1.234421  5.0  12
# 2022-06-21 -1.334034 -2.427709  0.648507  5.0  13
# 2022-06-22 -0.393233  1.344984 -0.110086  5.0  14
# 2022-06-23 -0.511189 -0.610947 -0.234703  5.0  15
# 2022-06-24 -0.728290  1.231819  0.430074  5.0  16
# 2022-06-25 -0.444771 -0.832265  1.604595  5.0  17
# 2022-06-26  0.378996 -0.507757  0.439415  5.0  18
# 2022-06-27  0.000805 -0.164564 -0.033391  5.0  19
# 2022-06-28 -0.679106  1.201701  0.100458  5.0  20

# %%
# setting values using a boolean selection (aka where clause)
df12[df12 > 0] = -df12
df12
# Out:
#                    A         B         C    D   F
# 2022-06-19  0.000000  0.000000 -0.967573 -5.0 -11
# 2022-06-20 -1.140042 -0.594597 -1.234421 -5.0 -12
# 2022-06-21 -1.334034 -2.427709 -0.648507 -5.0 -13
# 2022-06-22 -0.393233 -1.344984 -0.110086 -5.0 -14
# 2022-06-23 -0.511189 -0.610947 -0.234703 -5.0 -15
# 2022-06-24 -0.728290 -1.231819 -0.430074 -5.0 -16
# 2022-06-25 -0.444771 -0.832265 -1.604595 -5.0 -17
# 2022-06-26 -0.378996 -0.507757 -0.439415 -5.0 -18
# 2022-06-27 -0.000805 -0.164564 -0.033391 -5.0 -19
# 2022-06-28 -0.679106 -1.201701 -0.100458 -5.0 -20

# %% [markdown]
# # Missing Data

# %% [markdown]
# ### _reindex_
# change/add/delete index on a specified axis, returns a new dataframe

# %%
df13 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["G"])
df13
# Out:
#                    A         B         C         D   F   G
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852  11 NaN
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373  12 NaN
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819  13 NaN
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320  14 NaN

# %% [markdown]
# ### handling missing data
# 1. _```np.nan```_
# 1. _```pandas.isna()```_
# 1. ```df.dropna()```
# 1. ```df.fillna()```

# %%
# missing data in pandas is np.nan
df13.iat[1, 0] = np.nan
df13.iloc[1:, 5] = np.random.randint(1)
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852  11  NaN
# 2022-06-20       NaN  0.594597  1.234421 -1.050373  12  0.0
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819  13  0.0
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320  14  0.0

# %%
# get a boolean mask where values are NaN
df131 = pd.isna(df13)
df131
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# or just
pd.isna(df13)
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# the original is still there
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852  11  NaN
# 2022-06-20       NaN  0.594597  1.234421 -1.050373  12  0.0
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819  13  0.0
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320  14  0.0

# %%
# we are going to drop / replace values now, let's make a couple of copies of the dataframe
df132 = df13.copy()
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852  11  NaN
# 2022-06-20       NaN  0.594597  1.234421 -1.050373  12  0.0
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819  13  0.0
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320  14  0.0

# %%
# drop rows/columns that have missing data
# by default it returns a new dataframe, you may want to specify inplace=True for modifying current dataframe:
df_no_na = df132.dropna(how="any")
# how=‘any’ : If any NA values are present, drop that row or column.
# how=‘all’ : If all values are NA, drop that row or column.

# %%
# all rows/cols with missing data stripped
df_no_na
# Out:
#                    A         B         C         D   F    G
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819  13  0.0
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320  14  0.0

# %%
# original still intact
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852  11  NaN
# 2022-06-20       NaN  0.594597  1.234421 -1.050373  12  0.0
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819  13  0.0
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320  14  0.0

# %%
# drop missing data from original
df132.dropna(how="any", inplace=True)
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819  13  0.0
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320  14  0.0

# %%
# fill missing data
df133 = df13.copy()
df133.fillna(np.pi * 1000)
# Out:
#                       A         B         C         D   F            G
# 2022-06-19    -1.549685 -0.448156 -0.967573 -1.556852  11  3141.592654
# 2022-06-20  3141.592654  0.594597  1.234421 -1.050373  12     0.000000
# 2022-06-21    -1.334034 -2.427709  0.648507 -0.995819  13     0.000000
# 2022-06-22    -0.393233  1.344984 -0.110086 -0.341320  14     0.000000

# %% [markdown]
# # Align and Join

# %% [markdown]
# There needs to be a bigger notebook for this topic.
# You need to know there's "joins" in Pandas just like in the SQL world,
# like join and left join and right join and inner and outer and all that...
# Here we'll explore these in the context of the align function - 'aligning' the indexes of two dataframes.
# Later we'll see these again in the context of _merging_ two data frames.

# %% [markdown]
# ## Create two datasets with _mismatched_ indexes

# %%
# date range indexes
idx1 = pd.date_range("2022-01-01", periods=10)
# 2022-01-01', '2022-01-02' don't exist in idx2
# '2022-01-11', '2022-01-12' don't exist in idx1
idx2 = pd.date_range("2022-01-03", periods=10)

# %%
# dataframes from indexes
d1 = pd.DataFrame(
    index=idx1,
    data={"A": np.random.rand(10), "B": np.random.randint(1, high=25, size=10)},
)

d2 = pd.DataFrame(
    index=idx2,
    data={"A": np.random.rand(10), "B": np.random.randint(1, high=25, size=10)},
)

# %% [markdown]
# ## Quick Aside: Rendering two dataframes side-by-side

# %% [markdown]
# The trick of rendering 2 dataframes side-by-side was from [this](https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side) stackoverflow question.

# %%
# we gon need to display both data frames side by side, so...
from IPython.display import display_html


def render_df_side_by_side(a, b, a_title="", b_title=""):
    a_styler = a.style.set_table_attributes("style='display:inline'").set_caption(
        a_title
    )
    b_styler = b.style.set_table_attributes("style='display:inline'").set_caption(
        b_title
    )
    display_html(a_styler._repr_html_() + b_styler._repr_html_(), raw=True)

# %%
render_df_side_by_side(d1, d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5ca2e" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ca2e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_5ca2e_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ca2e_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_5ca2e_row0_col0" class="data row0 col0" >0.351908</td>
#       <td id="T_5ca2e_row0_col1" class="data row0 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_5ca2e_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_5ca2e_row1_col0" class="data row1 col0" >0.224626</td>
#       <td id="T_5ca2e_row1_col1" class="data row1 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_5ca2e_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_5ca2e_row2_col0" class="data row2 col0" >0.797751</td>
#       <td id="T_5ca2e_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_5ca2e_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_5ca2e_row3_col0" class="data row3 col0" >0.178406</td>
#       <td id="T_5ca2e_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_5ca2e_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_5ca2e_row4_col0" class="data row4 col0" >0.991701</td>
#       <td id="T_5ca2e_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5ca2e_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_5ca2e_row5_col0" class="data row5 col0" >0.325965</td>
#       <td id="T_5ca2e_row5_col1" class="data row5 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_5ca2e_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_5ca2e_row6_col0" class="data row6 col0" >0.966269</td>
#       <td id="T_5ca2e_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_5ca2e_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_5ca2e_row7_col0" class="data row7 col0" >0.220385</td>
#       <td id="T_5ca2e_row7_col1" class="data row7 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_5ca2e_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_5ca2e_row8_col0" class="data row8 col0" >0.796824</td>
#       <td id="T_5ca2e_row8_col1" class="data row8 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_5ca2e_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_5ca2e_row9_col0" class="data row9 col0" >0.711788</td>
#       <td id="T_5ca2e_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_7216b" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7216b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7216b_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7216b_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_7216b_row0_col0" class="data row0 col0" >0.561641</td>
#       <td id="T_7216b_row0_col1" class="data row0 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_7216b_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_7216b_row1_col0" class="data row1 col0" >0.490230</td>
#       <td id="T_7216b_row1_col1" class="data row1 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_7216b_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_7216b_row2_col0" class="data row2 col0" >0.558596</td>
#       <td id="T_7216b_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_7216b_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_7216b_row3_col0" class="data row3 col0" >0.075284</td>
#       <td id="T_7216b_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_7216b_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_7216b_row4_col0" class="data row4 col0" >0.003883</td>
#       <td id="T_7216b_row4_col1" class="data row4 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_7216b_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_7216b_row5_col0" class="data row5 col0" >0.953586</td>
#       <td id="T_7216b_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_7216b_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_7216b_row6_col0" class="data row6 col0" >0.571732</td>
#       <td id="T_7216b_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_7216b_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_7216b_row7_col0" class="data row7 col0" >0.800342</td>
#       <td id="T_7216b_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_7216b_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_7216b_row8_col0" class="data row8 col0" >0.506769</td>
#       <td id="T_7216b_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_7216b_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_7216b_row9_col0" class="data row9 col0" >0.630302</td>
#       <td id="T_7216b_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Table rendering/styling options is [a bigger discussion](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#) to be tackled later.

# %% [markdown]
# ## .add, .sub, .mul, .div etc.

# %% [markdown]
# flexible wrappers (```add, sub, mul, div, mod, pow```) to arithmetic operators: ```+, -, *, /, //, %, **```

# %%
# the +, -, *, /, //, %, ** operations align indexes to create a UNION of indexes
d3 = d1 + d2
d4 = d1.sub(d2)  # equivalent to d1-d2
d5 = d1 * d2
d6 = d1.div(d2)

# %%
# indexs not present in the other dataframe get a NaN

# pandas v1.x
# d3.style.highlight_null(null_color='red')

# pandas v2.x+
d3.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_2d044_row0_col0, #T_2d044_row0_col1, #T_2d044_row1_col0, #T_2d044_row1_col1, #T_2d044_row10_col0, #T_2d044_row10_col1, #T_2d044_row11_col0, #T_2d044_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_2d044">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d044_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_2d044_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d044_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_2d044_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_2d044_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2d044_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_2d044_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_2d044_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2d044_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_2d044_row2_col0" class="data row2 col0" >1.359392</td>
#       <td id="T_2d044_row2_col1" class="data row2 col1" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d044_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_2d044_row3_col0" class="data row3 col0" >0.668637</td>
#       <td id="T_2d044_row3_col1" class="data row3 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d044_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_2d044_row4_col0" class="data row4 col0" >1.550296</td>
#       <td id="T_2d044_row4_col1" class="data row4 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d044_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_2d044_row5_col0" class="data row5 col0" >0.401249</td>
#       <td id="T_2d044_row5_col1" class="data row5 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d044_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_2d044_row6_col0" class="data row6 col0" >0.970152</td>
#       <td id="T_2d044_row6_col1" class="data row6 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d044_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_2d044_row7_col0" class="data row7 col0" >1.173972</td>
#       <td id="T_2d044_row7_col1" class="data row7 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d044_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_2d044_row8_col0" class="data row8 col0" >1.368556</td>
#       <td id="T_2d044_row8_col1" class="data row8 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d044_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_2d044_row9_col0" class="data row9 col0" >1.512130</td>
#       <td id="T_2d044_row9_col1" class="data row9 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_2d044_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_2d044_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_2d044_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_2d044_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_2d044_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_2d044_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# sub
d4.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_1588e_row0_col0, #T_1588e_row0_col1, #T_1588e_row1_col0, #T_1588e_row1_col1, #T_1588e_row10_col0, #T_1588e_row10_col1, #T_1588e_row11_col0, #T_1588e_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_1588e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1588e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_1588e_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1588e_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_1588e_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_1588e_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1588e_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_1588e_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_1588e_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1588e_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_1588e_row2_col0" class="data row2 col0" >0.236110</td>
#       <td id="T_1588e_row2_col1" class="data row2 col1" >-2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1588e_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_1588e_row3_col0" class="data row3 col0" >-0.311824</td>
#       <td id="T_1588e_row3_col1" class="data row3 col1" >-8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1588e_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_1588e_row4_col0" class="data row4 col0" >0.433105</td>
#       <td id="T_1588e_row4_col1" class="data row4 col1" >-2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1588e_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_1588e_row5_col0" class="data row5 col0" >0.250681</td>
#       <td id="T_1588e_row5_col1" class="data row5 col1" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1588e_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_1588e_row6_col0" class="data row6 col0" >0.962385</td>
#       <td id="T_1588e_row6_col1" class="data row6 col1" >-5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1588e_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_1588e_row7_col0" class="data row7 col0" >-0.733201</td>
#       <td id="T_1588e_row7_col1" class="data row7 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1588e_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_1588e_row8_col0" class="data row8 col0" >0.225092</td>
#       <td id="T_1588e_row8_col1" class="data row8 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1588e_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_1588e_row9_col0" class="data row9 col0" >-0.088554</td>
#       <td id="T_1588e_row9_col1" class="data row9 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1588e_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_1588e_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_1588e_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1588e_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_1588e_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_1588e_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# mul
d5.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_7590d_row0_col0, #T_7590d_row0_col1, #T_7590d_row1_col0, #T_7590d_row1_col1, #T_7590d_row10_col0, #T_7590d_row10_col1, #T_7590d_row11_col0, #T_7590d_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_7590d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7590d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7590d_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7590d_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_7590d_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_7590d_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7590d_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_7590d_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_7590d_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7590d_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_7590d_row2_col0" class="data row2 col0" >0.448049</td>
#       <td id="T_7590d_row2_col1" class="data row2 col1" >195.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7590d_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_7590d_row3_col0" class="data row3 col0" >0.087460</td>
#       <td id="T_7590d_row3_col1" class="data row3 col1" >33.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7590d_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_7590d_row4_col0" class="data row4 col0" >0.553960</td>
#       <td id="T_7590d_row4_col1" class="data row4 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7590d_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_7590d_row5_col0" class="data row5 col0" >0.024540</td>
#       <td id="T_7590d_row5_col1" class="data row5 col1" >68.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7590d_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_7590d_row6_col0" class="data row6 col0" >0.003752</td>
#       <td id="T_7590d_row6_col1" class="data row6 col1" >84.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7590d_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_7590d_row7_col0" class="data row7 col0" >0.210157</td>
#       <td id="T_7590d_row7_col1" class="data row7 col1" >102.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7590d_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_7590d_row8_col0" class="data row8 col0" >0.455570</td>
#       <td id="T_7590d_row8_col1" class="data row8 col1" >126.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7590d_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_7590d_row9_col0" class="data row9 col0" >0.569674</td>
#       <td id="T_7590d_row9_col1" class="data row9 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7590d_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_7590d_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_7590d_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7590d_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_7590d_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_7590d_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# div
d6.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_1a23b_row0_col0, #T_1a23b_row0_col1, #T_1a23b_row1_col0, #T_1a23b_row1_col1, #T_1a23b_row10_col0, #T_1a23b_row10_col1, #T_1a23b_row11_col0, #T_1a23b_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_1a23b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a23b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_1a23b_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a23b_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_1a23b_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_1a23b_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1a23b_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_1a23b_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_1a23b_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1a23b_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_1a23b_row2_col0" class="data row2 col0" >1.420394</td>
#       <td id="T_1a23b_row2_col1" class="data row2 col1" >0.866667</td>
#     </tr>
#     <tr>
#       <th id="T_1a23b_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_1a23b_row3_col0" class="data row3 col0" >0.363924</td>
#       <td id="T_1a23b_row3_col1" class="data row3 col1" >0.272727</td>
#     </tr>
#     <tr>
#       <th id="T_1a23b_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_1a23b_row4_col0" class="data row4 col0" >1.775346</td>
#       <td id="T_1a23b_row4_col1" class="data row4 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_1a23b_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_1a23b_row5_col0" class="data row5 col0" >4.329794</td>
#       <td id="T_1a23b_row5_col1" class="data row5 col1" >4.250000</td>
#     </tr>
#     <tr>
#       <th id="T_1a23b_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_1a23b_row6_col0" class="data row6 col0" >248.827544</td>
#       <td id="T_1a23b_row6_col1" class="data row6 col1" >0.583333</td>
#     </tr>
#     <tr>
#       <th id="T_1a23b_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_1a23b_row7_col0" class="data row7 col0" >0.231112</td>
#       <td id="T_1a23b_row7_col1" class="data row7 col1" >2.833333</td>
#     </tr>
#     <tr>
#       <th id="T_1a23b_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_1a23b_row8_col0" class="data row8 col0" >1.393701</td>
#       <td id="T_1a23b_row8_col1" class="data row8 col1" >2.571429</td>
#     </tr>
#     <tr>
#       <th id="T_1a23b_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_1a23b_row9_col0" class="data row9 col0" >0.889354</td>
#       <td id="T_1a23b_row9_col1" class="data row9 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1a23b_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_1a23b_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_1a23b_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_1a23b_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_1a23b_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_1a23b_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### removing the NaN values from the resultant dataframe

# %%
# the + operation is UNION of indexes
d31 = d1 + d2
# indexs not present in the other dataframe get a NaN
# do you can obvs remove nan values like before
d3.dropna().style.highlight_null(color="red")
# Out:
# <style type="text/css">
# </style>
# <table id="T_0e734">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e734_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_0e734_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e734_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_0e734_row0_col0" class="data row0 col0" >1.359392</td>
#       <td id="T_0e734_row0_col1" class="data row0 col1" >28.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e734_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_0e734_row1_col0" class="data row1 col0" >0.668637</td>
#       <td id="T_0e734_row1_col1" class="data row1 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e734_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_0e734_row2_col0" class="data row2 col0" >1.550296</td>
#       <td id="T_0e734_row2_col1" class="data row2 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e734_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_0e734_row3_col0" class="data row3 col0" >0.401249</td>
#       <td id="T_0e734_row3_col1" class="data row3 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e734_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_0e734_row4_col0" class="data row4 col0" >0.970152</td>
#       <td id="T_0e734_row4_col1" class="data row4 col1" >19.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e734_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_0e734_row5_col0" class="data row5 col0" >1.173972</td>
#       <td id="T_0e734_row5_col1" class="data row5 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e734_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_0e734_row6_col0" class="data row6 col0" >1.368556</td>
#       <td id="T_0e734_row6_col1" class="data row6 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0e734_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_0e734_row7_col0" class="data row7 col0" >1.512130</td>
#       <td id="T_0e734_row7_col1" class="data row7 col1" >10.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## df.align()

# %% [markdown]
# Pandas [align](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.align.html) works to join the dataframes in interesting ways.

# %%
# align returns two dataframes - left and right as a result of a join
# default join is outer - the union of indices will be used as index for left and right
left, right = d1.align(d2, join="outer")
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7f3cc" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f3cc_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_7f3cc_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f3cc_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_7f3cc_row0_col0" class="data row0 col0" >0.351908</td>
#       <td id="T_7f3cc_row0_col1" class="data row0 col1" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f3cc_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_7f3cc_row1_col0" class="data row1 col0" >0.224626</td>
#       <td id="T_7f3cc_row1_col1" class="data row1 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f3cc_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_7f3cc_row2_col0" class="data row2 col0" >0.797751</td>
#       <td id="T_7f3cc_row2_col1" class="data row2 col1" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f3cc_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_7f3cc_row3_col0" class="data row3 col0" >0.178406</td>
#       <td id="T_7f3cc_row3_col1" class="data row3 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f3cc_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_7f3cc_row4_col0" class="data row4 col0" >0.991701</td>
#       <td id="T_7f3cc_row4_col1" class="data row4 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f3cc_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_7f3cc_row5_col0" class="data row5 col0" >0.325965</td>
#       <td id="T_7f3cc_row5_col1" class="data row5 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f3cc_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_7f3cc_row6_col0" class="data row6 col0" >0.966269</td>
#       <td id="T_7f3cc_row6_col1" class="data row6 col1" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f3cc_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_7f3cc_row7_col0" class="data row7 col0" >0.220385</td>
#       <td id="T_7f3cc_row7_col1" class="data row7 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f3cc_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_7f3cc_row8_col0" class="data row8 col0" >0.796824</td>
#       <td id="T_7f3cc_row8_col1" class="data row8 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f3cc_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_7f3cc_row9_col0" class="data row9 col0" >0.711788</td>
#       <td id="T_7f3cc_row9_col1" class="data row9 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7f3cc_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_7f3cc_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_7f3cc_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_7f3cc_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_7f3cc_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_7f3cc_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_bf39b" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf39b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_bf39b_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf39b_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_bf39b_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_bf39b_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_bf39b_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_bf39b_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_bf39b_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_bf39b_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_bf39b_row2_col0" class="data row2 col0" >0.561641</td>
#       <td id="T_bf39b_row2_col1" class="data row2 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bf39b_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_bf39b_row3_col0" class="data row3 col0" >0.490230</td>
#       <td id="T_bf39b_row3_col1" class="data row3 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bf39b_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_bf39b_row4_col0" class="data row4 col0" >0.558596</td>
#       <td id="T_bf39b_row4_col1" class="data row4 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bf39b_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_bf39b_row5_col0" class="data row5 col0" >0.075284</td>
#       <td id="T_bf39b_row5_col1" class="data row5 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bf39b_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_bf39b_row6_col0" class="data row6 col0" >0.003883</td>
#       <td id="T_bf39b_row6_col1" class="data row6 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bf39b_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_bf39b_row7_col0" class="data row7 col0" >0.953586</td>
#       <td id="T_bf39b_row7_col1" class="data row7 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bf39b_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_bf39b_row8_col0" class="data row8 col0" >0.571732</td>
#       <td id="T_bf39b_row8_col1" class="data row8 col1" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bf39b_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_bf39b_row9_col0" class="data row9 col0" >0.800342</td>
#       <td id="T_bf39b_row9_col1" class="data row9 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bf39b_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_bf39b_row10_col0" class="data row10 col0" >0.506769</td>
#       <td id="T_bf39b_row10_col1" class="data row10 col1" >21.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bf39b_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_bf39b_row11_col0" class="data row11 col0" >0.630302</td>
#       <td id="T_bf39b_row11_col1" class="data row11 col1" >6.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# inner join
left, right = d1.align(d2, join="inner")
render_df_side_by_side(d1, d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_40b91" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40b91_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_40b91_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40b91_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_40b91_row0_col0" class="data row0 col0" >0.351908</td>
#       <td id="T_40b91_row0_col1" class="data row0 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_40b91_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_40b91_row1_col0" class="data row1 col0" >0.224626</td>
#       <td id="T_40b91_row1_col1" class="data row1 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_40b91_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_40b91_row2_col0" class="data row2 col0" >0.797751</td>
#       <td id="T_40b91_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_40b91_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_40b91_row3_col0" class="data row3 col0" >0.178406</td>
#       <td id="T_40b91_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_40b91_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_40b91_row4_col0" class="data row4 col0" >0.991701</td>
#       <td id="T_40b91_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_40b91_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_40b91_row5_col0" class="data row5 col0" >0.325965</td>
#       <td id="T_40b91_row5_col1" class="data row5 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_40b91_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_40b91_row6_col0" class="data row6 col0" >0.966269</td>
#       <td id="T_40b91_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_40b91_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_40b91_row7_col0" class="data row7 col0" >0.220385</td>
#       <td id="T_40b91_row7_col1" class="data row7 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_40b91_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_40b91_row8_col0" class="data row8 col0" >0.796824</td>
#       <td id="T_40b91_row8_col1" class="data row8 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_40b91_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_40b91_row9_col0" class="data row9 col0" >0.711788</td>
#       <td id="T_40b91_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_5fe80" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5fe80_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_5fe80_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5fe80_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_5fe80_row0_col0" class="data row0 col0" >0.561641</td>
#       <td id="T_5fe80_row0_col1" class="data row0 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_5fe80_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_5fe80_row1_col0" class="data row1 col0" >0.490230</td>
#       <td id="T_5fe80_row1_col1" class="data row1 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_5fe80_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_5fe80_row2_col0" class="data row2 col0" >0.558596</td>
#       <td id="T_5fe80_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_5fe80_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_5fe80_row3_col0" class="data row3 col0" >0.075284</td>
#       <td id="T_5fe80_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_5fe80_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_5fe80_row4_col0" class="data row4 col0" >0.003883</td>
#       <td id="T_5fe80_row4_col1" class="data row4 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_5fe80_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_5fe80_row5_col0" class="data row5 col0" >0.953586</td>
#       <td id="T_5fe80_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_5fe80_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_5fe80_row6_col0" class="data row6 col0" >0.571732</td>
#       <td id="T_5fe80_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_5fe80_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_5fe80_row7_col0" class="data row7 col0" >0.800342</td>
#       <td id="T_5fe80_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5fe80_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_5fe80_row8_col0" class="data row8 col0" >0.506769</td>
#       <td id="T_5fe80_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_5fe80_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_5fe80_row9_col0" class="data row9 col0" >0.630302</td>
#       <td id="T_5fe80_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
# we can fill the NaNs with a certain value if needed
# let's fill with -100 so we can see it clearly
left, right = d1.align(d2, join="outer", fill_value=-100)
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f8e32" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8e32_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f8e32_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8e32_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_f8e32_row0_col0" class="data row0 col0" >0.351908</td>
#       <td id="T_f8e32_row0_col1" class="data row0 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_f8e32_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_f8e32_row1_col0" class="data row1 col0" >0.224626</td>
#       <td id="T_f8e32_row1_col1" class="data row1 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_f8e32_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_f8e32_row2_col0" class="data row2 col0" >0.797751</td>
#       <td id="T_f8e32_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_f8e32_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_f8e32_row3_col0" class="data row3 col0" >0.178406</td>
#       <td id="T_f8e32_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f8e32_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_f8e32_row4_col0" class="data row4 col0" >0.991701</td>
#       <td id="T_f8e32_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f8e32_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_f8e32_row5_col0" class="data row5 col0" >0.325965</td>
#       <td id="T_f8e32_row5_col1" class="data row5 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_f8e32_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_f8e32_row6_col0" class="data row6 col0" >0.966269</td>
#       <td id="T_f8e32_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_f8e32_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_f8e32_row7_col0" class="data row7 col0" >0.220385</td>
#       <td id="T_f8e32_row7_col1" class="data row7 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_f8e32_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_f8e32_row8_col0" class="data row8 col0" >0.796824</td>
#       <td id="T_f8e32_row8_col1" class="data row8 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_f8e32_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_f8e32_row9_col0" class="data row9 col0" >0.711788</td>
#       <td id="T_f8e32_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f8e32_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_f8e32_row10_col0" class="data row10 col0" >-100.000000</td>
#       <td id="T_f8e32_row10_col1" class="data row10 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_f8e32_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_f8e32_row11_col0" class="data row11 col0" >-100.000000</td>
#       <td id="T_f8e32_row11_col1" class="data row11 col1" >-100</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_9ff94" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ff94_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_9ff94_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ff94_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_9ff94_row0_col0" class="data row0 col0" >-100.000000</td>
#       <td id="T_9ff94_row0_col1" class="data row0 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_9ff94_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_9ff94_row1_col0" class="data row1 col0" >-100.000000</td>
#       <td id="T_9ff94_row1_col1" class="data row1 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_9ff94_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_9ff94_row2_col0" class="data row2 col0" >0.561641</td>
#       <td id="T_9ff94_row2_col1" class="data row2 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_9ff94_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_9ff94_row3_col0" class="data row3 col0" >0.490230</td>
#       <td id="T_9ff94_row3_col1" class="data row3 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_9ff94_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_9ff94_row4_col0" class="data row4 col0" >0.558596</td>
#       <td id="T_9ff94_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9ff94_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_9ff94_row5_col0" class="data row5 col0" >0.075284</td>
#       <td id="T_9ff94_row5_col1" class="data row5 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_9ff94_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_9ff94_row6_col0" class="data row6 col0" >0.003883</td>
#       <td id="T_9ff94_row6_col1" class="data row6 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_9ff94_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_9ff94_row7_col0" class="data row7 col0" >0.953586</td>
#       <td id="T_9ff94_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_9ff94_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_9ff94_row8_col0" class="data row8 col0" >0.571732</td>
#       <td id="T_9ff94_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_9ff94_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_9ff94_row9_col0" class="data row9 col0" >0.800342</td>
#       <td id="T_9ff94_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_9ff94_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_9ff94_row10_col0" class="data row10 col0" >0.506769</td>
#       <td id="T_9ff94_row10_col1" class="data row10 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_9ff94_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_9ff94_row11_col0" class="data row11 col0" >0.630302</td>
#       <td id="T_9ff94_row11_col1" class="data row11 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
# left join: left index is added to right, but not the other way
left, right = d1.align(d2, join="left")
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_db27e" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db27e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_db27e_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db27e_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_db27e_row0_col0" class="data row0 col0" >0.351908</td>
#       <td id="T_db27e_row0_col1" class="data row0 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_db27e_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_db27e_row1_col0" class="data row1 col0" >0.224626</td>
#       <td id="T_db27e_row1_col1" class="data row1 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_db27e_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_db27e_row2_col0" class="data row2 col0" >0.797751</td>
#       <td id="T_db27e_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_db27e_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_db27e_row3_col0" class="data row3 col0" >0.178406</td>
#       <td id="T_db27e_row3_col1" class="data row3 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_db27e_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_db27e_row4_col0" class="data row4 col0" >0.991701</td>
#       <td id="T_db27e_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_db27e_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_db27e_row5_col0" class="data row5 col0" >0.325965</td>
#       <td id="T_db27e_row5_col1" class="data row5 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_db27e_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_db27e_row6_col0" class="data row6 col0" >0.966269</td>
#       <td id="T_db27e_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_db27e_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_db27e_row7_col0" class="data row7 col0" >0.220385</td>
#       <td id="T_db27e_row7_col1" class="data row7 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_db27e_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_db27e_row8_col0" class="data row8 col0" >0.796824</td>
#       <td id="T_db27e_row8_col1" class="data row8 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_db27e_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_db27e_row9_col0" class="data row9 col0" >0.711788</td>
#       <td id="T_db27e_row9_col1" class="data row9 col1" >5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f0c8d" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0c8d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f0c8d_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f0c8d_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_f0c8d_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_f0c8d_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f0c8d_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_f0c8d_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_f0c8d_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_f0c8d_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_f0c8d_row2_col0" class="data row2 col0" >0.561641</td>
#       <td id="T_f0c8d_row2_col1" class="data row2 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f0c8d_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_f0c8d_row3_col0" class="data row3 col0" >0.490230</td>
#       <td id="T_f0c8d_row3_col1" class="data row3 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f0c8d_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_f0c8d_row4_col0" class="data row4 col0" >0.558596</td>
#       <td id="T_f0c8d_row4_col1" class="data row4 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f0c8d_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_f0c8d_row5_col0" class="data row5 col0" >0.075284</td>
#       <td id="T_f0c8d_row5_col1" class="data row5 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f0c8d_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_f0c8d_row6_col0" class="data row6 col0" >0.003883</td>
#       <td id="T_f0c8d_row6_col1" class="data row6 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f0c8d_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_f0c8d_row7_col0" class="data row7 col0" >0.953586</td>
#       <td id="T_f0c8d_row7_col1" class="data row7 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f0c8d_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_f0c8d_row8_col0" class="data row8 col0" >0.571732</td>
#       <td id="T_f0c8d_row8_col1" class="data row8 col1" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f0c8d_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_f0c8d_row9_col0" class="data row9 col0" >0.800342</td>
#       <td id="T_f0c8d_row9_col1" class="data row9 col1" >5.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# right join: right index is added to left, but not the other way
left, right = d1.align(d2, join="right")
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fa775" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fa775_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_fa775_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa775_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_fa775_row0_col0" class="data row0 col0" >0.797751</td>
#       <td id="T_fa775_row0_col1" class="data row0 col1" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa775_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_fa775_row1_col0" class="data row1 col0" >0.178406</td>
#       <td id="T_fa775_row1_col1" class="data row1 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa775_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_fa775_row2_col0" class="data row2 col0" >0.991701</td>
#       <td id="T_fa775_row2_col1" class="data row2 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa775_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_fa775_row3_col0" class="data row3 col0" >0.325965</td>
#       <td id="T_fa775_row3_col1" class="data row3 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa775_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_fa775_row4_col0" class="data row4 col0" >0.966269</td>
#       <td id="T_fa775_row4_col1" class="data row4 col1" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa775_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_fa775_row5_col0" class="data row5 col0" >0.220385</td>
#       <td id="T_fa775_row5_col1" class="data row5 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa775_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_fa775_row6_col0" class="data row6 col0" >0.796824</td>
#       <td id="T_fa775_row6_col1" class="data row6 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa775_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_fa775_row7_col0" class="data row7 col0" >0.711788</td>
#       <td id="T_fa775_row7_col1" class="data row7 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fa775_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_fa775_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_fa775_row8_col1" class="data row8 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fa775_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_fa775_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_fa775_row9_col1" class="data row9 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f46df" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f46df_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_f46df_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f46df_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_f46df_row0_col0" class="data row0 col0" >0.561641</td>
#       <td id="T_f46df_row0_col1" class="data row0 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_f46df_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_f46df_row1_col0" class="data row1 col0" >0.490230</td>
#       <td id="T_f46df_row1_col1" class="data row1 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_f46df_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_f46df_row2_col0" class="data row2 col0" >0.558596</td>
#       <td id="T_f46df_row2_col1" class="data row2 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_f46df_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_f46df_row3_col0" class="data row3 col0" >0.075284</td>
#       <td id="T_f46df_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_f46df_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_f46df_row4_col0" class="data row4 col0" >0.003883</td>
#       <td id="T_f46df_row4_col1" class="data row4 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_f46df_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_f46df_row5_col0" class="data row5 col0" >0.953586</td>
#       <td id="T_f46df_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_f46df_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_f46df_row6_col0" class="data row6 col0" >0.571732</td>
#       <td id="T_f46df_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_f46df_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_f46df_row7_col0" class="data row7 col0" >0.800342</td>
#       <td id="T_f46df_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_f46df_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_f46df_row8_col0" class="data row8 col0" >0.506769</td>
#       <td id="T_f46df_row8_col1" class="data row8 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_f46df_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_f46df_row9_col0" class="data row9 col0" >0.630302</td>
#       <td id="T_f46df_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There's more to explore in align, and it can get confusing, so beginners be careful, take time and try to work out the result before you execute to build intuition.

# %% [markdown]
# # Operations on data

# %% [markdown]
# ## Stats
#
# Operations in general *exclude* missing data

# %%
# arithmetic mean, for each column (axis = 0)
df.mean()
# Out:
# A    -0.412047
# B    -0.061830
# C     0.311172
# D    -0.079617
# F    15.500000
# dtype: float64

# %%
# mean across a row (axis = 1)
df.mean(1)
# Out:
# 2022-06-19    1.295547
# 2022-06-20    2.783737
# 2022-06-21    1.778189
# 2022-06-22    2.900069
# 2022-06-23    2.706891
# 2022-06-24    3.576163
# 2022-06-25    3.521435
# 2022-06-26    3.958173
# 2022-06-27    3.930841
# 2022-06-28    4.064312
# Freq: D, dtype: float64

# %% [markdown]
# ## Apply

# %%
# apply custom lambdas
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.689727
# B    3.772693
# C    2.572168
# D    3.037060
# F    9.000000
# dtype: float64

# %%
df
# Out:
#                    A         B         C         D   F
# 2022-06-19 -1.549685 -0.448156 -0.967573 -1.556852  11
# 2022-06-20  1.140042  0.594597  1.234421 -1.050373  12
# 2022-06-21 -1.334034 -2.427709  0.648507 -0.995819  13
# 2022-06-22 -0.393233  1.344984 -0.110086 -0.341320  14
# 2022-06-23 -0.511189 -0.610947 -0.234703 -0.108703  15
# 2022-06-24 -0.728290  1.231819  0.430074  0.947210  16
# 2022-06-25 -0.444771 -0.832265  1.604595  0.279618  17
# 2022-06-26  0.378996 -0.507757  0.439415  1.480208  18
# 2022-06-27  0.000805 -0.164564 -0.033391  0.851357  19
# 2022-06-28 -0.679106  1.201701  0.100458 -0.301494  20

# %%
# each subsequent value is a sum of all values before it in the respective column
cumsum_df = df.apply(np.cumsum)
render_df_side_by_side(df, cumsum_df, "OG Dataframe", "Cumulative Sum")
# Out:
# <style type="text/css">
# </style>
# <table id="T_8e29e" style='display:inline'>
#   <caption>OG Dataframe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8e29e_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_8e29e_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_8e29e_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_8e29e_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_8e29e_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e29e_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_8e29e_row0_col0" class="data row0 col0" >-1.549685</td>
#       <td id="T_8e29e_row0_col1" class="data row0 col1" >-0.448156</td>
#       <td id="T_8e29e_row0_col2" class="data row0 col2" >-0.967573</td>
#       <td id="T_8e29e_row0_col3" class="data row0 col3" >-1.556852</td>
#       <td id="T_8e29e_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_8e29e_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_8e29e_row1_col0" class="data row1 col0" >1.140042</td>
#       <td id="T_8e29e_row1_col1" class="data row1 col1" >0.594597</td>
#       <td id="T_8e29e_row1_col2" class="data row1 col2" >1.234421</td>
#       <td id="T_8e29e_row1_col3" class="data row1 col3" >-1.050373</td>
#       <td id="T_8e29e_row1_col4" class="data row1 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_8e29e_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_8e29e_row2_col0" class="data row2 col0" >-1.334034</td>
#       <td id="T_8e29e_row2_col1" class="data row2 col1" >-2.427709</td>
#       <td id="T_8e29e_row2_col2" class="data row2 col2" >0.648507</td>
#       <td id="T_8e29e_row2_col3" class="data row2 col3" >-0.995819</td>
#       <td id="T_8e29e_row2_col4" class="data row2 col4" >13</td>
#     </tr>
#     <tr>
#       <th id="T_8e29e_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_8e29e_row3_col0" class="data row3 col0" >-0.393233</td>
#       <td id="T_8e29e_row3_col1" class="data row3 col1" >1.344984</td>
#       <td id="T_8e29e_row3_col2" class="data row3 col2" >-0.110086</td>
#       <td id="T_8e29e_row3_col3" class="data row3 col3" >-0.341320</td>
#       <td id="T_8e29e_row3_col4" class="data row3 col4" >14</td>
#     </tr>
#     <tr>
#       <th id="T_8e29e_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_8e29e_row4_col0" class="data row4 col0" >-0.511189</td>
#       <td id="T_8e29e_row4_col1" class="data row4 col1" >-0.610947</td>
#       <td id="T_8e29e_row4_col2" class="data row4 col2" >-0.234703</td>
#       <td id="T_8e29e_row4_col3" class="data row4 col3" >-0.108703</td>
#       <td id="T_8e29e_row4_col4" class="data row4 col4" >15</td>
#     </tr>
#     <tr>
#       <th id="T_8e29e_level0_row5" class="row_heading level0 row5" >2022-06-24 00:00:00</th>
#       <td id="T_8e29e_row5_col0" class="data row5 col0" >-0.728290</td>
#       <td id="T_8e29e_row5_col1" class="data row5 col1" >1.231819</td>
#       <td id="T_8e29e_row5_col2" class="data row5 col2" >0.430074</td>
#       <td id="T_8e29e_row5_col3" class="data row5 col3" >0.947210</td>
#       <td id="T_8e29e_row5_col4" class="data row5 col4" >16</td>
#     </tr>
#     <tr>
#       <th id="T_8e29e_level0_row6" class="row_heading level0 row6" >2022-06-25 00:00:00</th>
#       <td id="T_8e29e_row6_col0" class="data row6 col0" >-0.444771</td>
#       <td id="T_8e29e_row6_col1" class="data row6 col1" >-0.832265</td>
#       <td id="T_8e29e_row6_col2" class="data row6 col2" >1.604595</td>
#       <td id="T_8e29e_row6_col3" class="data row6 col3" >0.279618</td>
#       <td id="T_8e29e_row6_col4" class="data row6 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_8e29e_level0_row7" class="row_heading level0 row7" >2022-06-26 00:00:00</th>
#       <td id="T_8e29e_row7_col0" class="data row7 col0" >0.378996</td>
#       <td id="T_8e29e_row7_col1" class="data row7 col1" >-0.507757</td>
#       <td id="T_8e29e_row7_col2" class="data row7 col2" >0.439415</td>
#       <td id="T_8e29e_row7_col3" class="data row7 col3" >1.480208</td>
#       <td id="T_8e29e_row7_col4" class="data row7 col4" >18</td>
#     </tr>
#     <tr>
#       <th id="T_8e29e_level0_row8" class="row_heading level0 row8" >2022-06-27 00:00:00</th>
#       <td id="T_8e29e_row8_col0" class="data row8 col0" >0.000805</td>
#       <td id="T_8e29e_row8_col1" class="data row8 col1" >-0.164564</td>
#       <td id="T_8e29e_row8_col2" class="data row8 col2" >-0.033391</td>
#       <td id="T_8e29e_row8_col3" class="data row8 col3" >0.851357</td>
#       <td id="T_8e29e_row8_col4" class="data row8 col4" >19</td>
#     </tr>
#     <tr>
#       <th id="T_8e29e_level0_row9" class="row_heading level0 row9" >2022-06-28 00:00:00</th>
#       <td id="T_8e29e_row9_col0" class="data row9 col0" >-0.679106</td>
#       <td id="T_8e29e_row9_col1" class="data row9 col1" >1.201701</td>
#       <td id="T_8e29e_row9_col2" class="data row9 col2" >0.100458</td>
#       <td id="T_8e29e_row9_col3" class="data row9 col3" >-0.301494</td>
#       <td id="T_8e29e_row9_col4" class="data row9 col4" >20</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_fab52" style='display:inline'>
#   <caption>Cumulative Sum</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fab52_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_fab52_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_fab52_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_fab52_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_fab52_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fab52_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_fab52_row0_col0" class="data row0 col0" >-1.549685</td>
#       <td id="T_fab52_row0_col1" class="data row0 col1" >-0.448156</td>
#       <td id="T_fab52_row0_col2" class="data row0 col2" >-0.967573</td>
#       <td id="T_fab52_row0_col3" class="data row0 col3" >-1.556852</td>
#       <td id="T_fab52_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_fab52_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_fab52_row1_col0" class="data row1 col0" >-0.409643</td>
#       <td id="T_fab52_row1_col1" class="data row1 col1" >0.146441</td>
#       <td id="T_fab52_row1_col2" class="data row1 col2" >0.266848</td>
#       <td id="T_fab52_row1_col3" class="data row1 col3" >-2.607225</td>
#       <td id="T_fab52_row1_col4" class="data row1 col4" >23</td>
#     </tr>
#     <tr>
#       <th id="T_fab52_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_fab52_row2_col0" class="data row2 col0" >-1.743677</td>
#       <td id="T_fab52_row2_col1" class="data row2 col1" >-2.281268</td>
#       <td id="T_fab52_row2_col2" class="data row2 col2" >0.915355</td>
#       <td id="T_fab52_row2_col3" class="data row2 col3" >-3.603044</td>
#       <td id="T_fab52_row2_col4" class="data row2 col4" >36</td>
#     </tr>
#     <tr>
#       <th id="T_fab52_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_fab52_row3_col0" class="data row3 col0" >-2.136911</td>
#       <td id="T_fab52_row3_col1" class="data row3 col1" >-0.936283</td>
#       <td id="T_fab52_row3_col2" class="data row3 col2" >0.805269</td>
#       <td id="T_fab52_row3_col3" class="data row3 col3" >-3.944364</td>
#       <td id="T_fab52_row3_col4" class="data row3 col4" >50</td>
#     </tr>
#     <tr>
#       <th id="T_fab52_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_fab52_row4_col0" class="data row4 col0" >-2.648100</td>
#       <td id="T_fab52_row4_col1" class="data row4 col1" >-1.547230</td>
#       <td id="T_fab52_row4_col2" class="data row4 col2" >0.570566</td>
#       <td id

# %% [markdown]
# ## Histogramming
#
# Frequencies, 'nuff said
#
# ```value_counts()```

# %%
series1 = pd.Series(np.random.randint(0, 5, size=25))
series1.value_counts()
# Out:
# 1    7
# 4    7
# 0    5
# 3    4
# 2    2
# Name: count, dtype: int64

# %% [markdown]
# ## String Methods

# %%
# build a series
some_string = "SERIes and Index are EqUIppeD WITh A seT Of stRINg PROCESSING METHoDs In tHe ```sTR``` attrIBute THAT MakE IT eASy To oPerATE ON EACh ELEmeNt OF The aRrAY. NOtE thAt PAtTERN-maTching in ```sTR``` gENeralLY UsES reGUlAr eXpreSsiONs bY DEfault (aND In Some cases AlwayS uSEs tHeM)."
str_series = pd.Series(some_string.split())  # split splits on whitespace by default

# %%
# manipulating the case - lower, upper etc.
# also the length of each string, split, replace, yada yada...
# very important when cleaning data (column names may have stupid whitespace, bad case, spacing etc.)
low = str_series.str.lower()
up = str_series.str.upper()

low_up_df = pd.DataFrame(
    {
        "og": str_series,
        "length": str_series.str.len(),
        "low": low,
        "up": up,
        "split_low_on_i": low.str.split(
            "i", expand=False
        ),  # expand = True will break this usecase, try elsewhere
        "replace_a_with_star_in_low": low.str.replace(
            "a", "*", case=False, regex=True
        ),  # yeah, you can mess with regular expns
    }
)

low_up_df.tail(10)
# Out:
#              og  length          low           up  split_low_on_i  \
# 36  eXpreSsiONs      11  expressions  EXPRESSIONS  [express, ons]
# 37           bY       2           by           BY            [by]
# 38      DEfault       7      default      DEFAULT       [default]
# 39         (aND       4         (and         (AND          [(and]
# 40           In       2           in           IN           [, n]
# 41         Some       4         some         SOME          [some]
# 42        cases       5        cases        CASES         [cases]
# 43       AlwayS       6       always       ALWAYS        [always]
# 44         uSEs       4         uses         USES          [uses]
# 45       tHeM).       6       them).       THEM).        [them).]
#
#    replace_a_with_star_in_low
# 36                expressions
# 37                         by
# 38                    def*ult
# 39                       (*nd
# 40                         in
# 41                       some
# 42                      c*ses
# 43                     *lw*ys
# 44                       uses
# 45                     them).

# %% [markdown]
# See [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#text-string-methods) for more string operations.

# %% [markdown]
# # Merge
#
# Combine series and dataframes, use set logic for indexes and relational algebra for joins/merges

# %% [markdown]
# ## Concat
#
# Chill, we've done this before. The same join = inner/outer/left/right drill.

# %%
# let's make some more dataframes
concatDF = pd.DataFrame(
    np.random.randn(10, 4)
)  # 10 rows and 4 columns of random numbers
pieces = [concatDF[:3], concatDF[3:7], concatDF[7:]]
reconstructedDF = pd.concat(pieces)
display("broken DFs: ", pieces)
render_df_side_by_side(concatDF, reconstructedDF, "OG", "Concatenated")
# Out:
# 'broken DFs: '
# [          0         1         2         3
#  0  0.516235 -1.081323 -0.588541  0.156023
#  1  0.058886 -0.415804  1.168519 -2.389338
#  2 -1.340235  0.166527 -0.604575 -0.245738,
#            0         1         2         3
#  3 -1.378420 -1.072956 -1.084109  0.252270
#  4  0.187984  0.685665  0.644224 -0.029137
#  5 -0.156130 -0.059620 -0.486168  0.313524
#  6 -0.592934 -0.538696 -1.327662 -0.651596,
#            0         1         2         3
#  7  0.909241  0.052438 -0.178248  0.050835
#  8 -0.142048 -0.965511  1.688367 -0.601909
#  9  1.207313  0.360771 -1.359410  0.319240]
# <style type="text/css">
# </style>
# <table id="T_d8178" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8178_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_d8178_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_d8178_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_d8178_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8178_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8178_row0_col0" class="data row0 col0" >0.516235</td>
#       <td id="T_d8178_row0_col1" class="data row0 col1" >-1.081323</td>
#       <td id="T_d8178_row0_col2" class="data row0 col2" >-0.588541</td>
#       <td id="T_d8178_row0_col3" class="data row0 col3" >0.156023</td>
#     </tr>
#     <tr>
#       <th id="T_d8178_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d8178_row1_col0" class="data row1 col0" >0.058886</td>
#       <td id="T_d8178_row1_col1" class="data row1 col1" >-0.415804</td>
#       <td id="T_d8178_row1_col2" class="data row1 col2" >1.168519</td>
#       <td id="T_d8178_row1_col3" class="data row1 col3" >-2.389338</td>
#     </tr>
#     <tr>
#       <th id="T_d8178_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d8178_row2_col0" class="data row2 col0" >-1.340235</td>
#       <td id="T_d8178_row2_col1" class="data row2 col1" >0.166527</td>
#       <td id="T_d8178_row2_col2" class="data row2 col2" >-0.604575</td>
#       <td id="T_d8178_row2_col3" class="data row2 col3" >-0.245738</td>
#     </tr>
#     <tr>
#       <th id="T_d8178_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d8178_row3_col0" class="data row3 col0" >-1.378420</td>
#       <td id="T_d8178_row3_col1" class="data row3 col1" >-1.072956</td>
#       <td id="T_d8178_row3_col2" class="data row3 col2" >-1.084109</td>
#       <td id="T_d8178_row3_col3" class="data row3 col3" >0.252270</td>
#     </tr>
#     <tr>
#       <th id="T_d8178_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d8178_row4_col0" class="data row4 col0" >0.187984</td>
#       <td id="T_d8178_row4_col1" class="data row4 col1" >0.685665</td>
#       <td id="T_d8178_row4_col2" class="data row4 col2" >0.644224</td>
#       <td id="T_d8178_row4_col3" class="data row4 col3" >-0.029137</td>
#     </tr>
#     <tr>
#       <th id="T_d8178_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d8178_row5_col0" class="data row5 col0" >-0.156130</td>
#       <td id="T_d8178_row5_col1" class="data row5 col1" >-0.059620</td>
#       <td id="T_d8178_row5_col2" class="data row5 col2" >-0.486168</td>
#       <td id="T_d8178_row5_col3" class="data row5 col3" >0.313524</td>
#     </tr>
#     <tr>
#       <th id="T_d8178_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d8178_row6_col0" class="data row6 col0" >-0.592934</td>
#       <td id="T_d8178_row6_col1" class="data row6 col1" >-0.538696</td>
#       <td id="T_d8178_row6_col2" class="data row6 col2" >-1.327662</td>
#       <td id="T_d8178_row6_col3" class="data row6 col3" >-0.651596</td>
#     </tr>
#     <tr>
#       <th id="T_d8178_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d8178_row7_col0" class="data row7 col0" >0.909241</td>
#       <td id="T_d8178_row7_col1" class="data row7 col1" >0.052438</td>
#       <td id="T_d8178_row7_col2" class="data row7 col2" >-0.178248</td>
#       <td id="T_d8178_row7_col3" class="data row7 col3" >0.050835</td>
#     </tr>
#     <tr>
#       <th id="T_d8178_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d8178_row8_col0" class="data row8 col0" >-0.142048</td>
#       <td id="T_d8178_row8_col1" class="data row8 col1" >-0.965511</td>
#       <td id="T_d8178_row8_col2" class="data row8 col2" >1.688367</td>
#       <td id="T_d8178_row8_col3" class="data row8 col3" >-0.601909</td>
#     </tr>
#     <tr>
#       <th id="T_d8178_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d8178_row9_col0" class="data row9 col0" >1.207313</td>
#       <td id="T_d8178_row9_col1" class="data row9 col1" >0.360771</td>
#       <td id="T_d8178_row9_col2" class="data row9 col2" >-1.359410</td>
#       <td id="T_d8178_row9_col3" class="data row9 col3" >0.319240</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_67323" style='display:inline'>
#   <caption>Concatenated</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67323_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_67323_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_67323_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_67323_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67323_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_67323_row0_col0" class="data row0 col0" >0.516235</td>
#       <td id="T_67323_row0_col1" class="data row0 col1" >-1.081323</td>
#       <td id="T_67323_row0_col2" class="data row0 col2" >-0.588541</td>
#       <td id="T_67323_row0_col3" class="data row0 col3" >0.156023</td>
#     </tr>
#     <tr>
#       <th id="T_67323_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_67323_row1_col0" class="data row1 col0" >0.058886</td>
#       <td id="T_67323_row1_col1" class="data row1 col1" >-0.415804</td>
#       <td id="T_67323_row1_col2" class="data row1 col2" >1.168519</td>
#       <td id="T_67323_row1_col3" class="data row1 col3" >-2.389338</td>
#     </tr>
#     <tr>
#       <th id="T_67323_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_67323_row2_col0" class="data row2 col0" >-1.340235</td>
#       <td id="T_67323_row2_col1" class="data row2 col1" >0.166527</td>
#       <td id="T_67323_row2_col2" class="data row2 col2" >-0.604575</td>
#       <td id="T_67323_row2_col3" class="data row2 col3" >-0.245738</td>
#     </tr>
#     <tr>
#       <th id="T_67323_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_67323_row3_col0" class="data row3 col0" >-1.378420</td>
#       <td id="T_67323_row3_col1" class="data row3 col1" >-1.072956</td>
#       <td id="T_67323_row3_col2" class="data row3 col2" >-1.084109</td>
#       <td id="T_67323_row3_col3" class="data row3 col3" >0.252270</td>
#     </tr>
#     <tr>
#       <th id="T_67323_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_67323_row4_col0" class="data row4 col0" >0.187984</td>
#       <td id="T_67323_row4_col1" class="data row4 col1" >0.685665</td>
#       <td id="T_67323_row4_col2" class="data row4 col2" >0.644224</td>
#       <td id="T_67323_row4_col3" class="data row4 col3" >-0.029137</td>
#     </tr>
#     <tr>
#       <th id="T_67323_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_67323_row5_col0" class="data row5 col0" >-0.156130</td>
#       <td id="T_67323_row5_col1" class="data row5 col1" >-0.059620</td>
#       <td id="T_67323_row5_col2" class="data row5 col2" >-0.486168</td>
#       <td id="T_67323_row5_col3" class="data row5 col3" >0.313524</td>
#     </tr>
#     <tr>
#       <th id="T_67323_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_67323_row6_col0" class="data row6 col0" >-0.592934</td>
#       <td id="T_67323_row6_col1" class="data row6 col1" >-0.538696</td>
#       <td id="T_67323_row6_col2" class="data row6 col2" >-1.327662</td>
#       <td id="T_67323_row6_col3" class="data row6 col3" >-0.651596</td>
#     </tr>
#     <tr>
#       <th id="T_67323_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_67323_row7_col0" class="data row7 col0" >0.909241</td>
#       <td id="T_67323_row7_col1" class="data row7 col1" >0.052438</td>
#       <td id="T_67323_row7_col2" class="data row7 col2" >-0.178248</td>
#       <td id="T_67323_row7_col3" class="data row7 col3" >0.050835</td>
#     </tr>
#     <tr>
#       <th id="T_67323_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_67323_row8_col0" class="data row8

# %% [markdown]
# _From the [page](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html#concat)_:
# Adding a column to a DataFrame is relatively fast. However, adding a row requires a copy, and may be expensive. We recommend passing a pre-built list of records to the DataFrame constructor instead of building a DataFrame by iteratively appending records to it.

# %% [markdown]
# ## Join
# SQL style merges.

# %%
# two data frames
sl = pd.Series(np.random.randint(10, size=6))
sr = sl.shift(2).fillna(0).astype(int)
left = pd.DataFrame({"key": list("ABCDEF"), "lval": sl})

right = pd.DataFrame({"key": list("ABBCDE"), "rval": sr})

# %%
render_df_side_by_side(left, right, "left", "right")
# Out:
# <style type="text/css">
# </style>
# <table id="T_5bfaa" style='display:inline'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bfaa_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_5bfaa_level0_col1" class="col_heading level0 col1" >lval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bfaa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5bfaa_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_5bfaa_row0_col1" class="data row0 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_5bfaa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5bfaa_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_5bfaa_row1_col1" class="data row1 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_5bfaa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5bfaa_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_5bfaa_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_5bfaa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5bfaa_row3_col0" class="data row3 col0" >D</td>
#       <td id="T_5bfaa_row3_col1" class="data row3 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_5bfaa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5bfaa_row4_col0" class="data row4 col0" >E</td>
#       <td id="T_5bfaa_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_5bfaa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5bfaa_row5_col0" class="data row5 col0" >F</td>
#       <td id="T_5bfaa_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_855b8" style='display:inline'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_855b8_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_855b8_level0_col1" class="col_heading level0 col1" >rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_855b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_855b8_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_855b8_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_855b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_855b8_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_855b8_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_855b8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_855b8_row2_col0" class="data row2 col0" >B</td>
#       <td id="T_855b8_row2_col1" class="data row2 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_855b8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_855b8_row3_col0" class="data row3 col0" >C</td>
#       <td id="T_855b8_row3_col1" class="data row3 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_855b8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_855b8_row4_col0" class="data row4 col0" >D</td>
#       <td id="T_855b8_row4_col1" class="data row4 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_855b8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_855b8_row5_col0" class="data row5 col0" >E</td>
#       <td id="T_855b8_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = pd.merge(left, right, on="key")
result
# Out:
#   key  lval  rval
# 0   A     7     0
# 1   B     6     0
# 2   B     6     7
# 3   C     6     6
# 4   D     7     6
# 5   E     4     7

# %% [markdown]
# # Grouping

# %% [markdown]
# "Group By" really means one or more of the following happening:
# 1. **Split**: data is broken into groups based on some criteria
# 2. **Apply**: a data operation is executed on each of those groups
# 3. **Combine**: the results are combined back into a data structure

# %%
grp_df = pd.DataFrame(
    {
        "colA": list("AABCAABDAA"),
        "colB": list("1234567890"),
        "colC": np.random.randn(10),
        "colD": np.random.randn(10),
    }
)
grp_df
# Out:
#   colA colB      colC      colD
# 0    A    1 -0.917516  0.371238
# 1    A    2  0.728666  0.823692
# 2    B    3 -1.223632  0.563674
# 3    C    4 -0.042648 -0.109007
# 4    A    5  1.274853 -0.222768
# 5    A    6 -0.701205  0.059788
# 6    B    7 -0.487083  0.194251
# 7    D    8 -1.254922  0.239682
# 8    A    9  0.336358  2.087440
# 9    A    0  1.525196 -0.970353

# %%
# a DataFrameGroupBy object object
grpby = grp_df.groupby("colA")

# list all the groups found
g = grpby.groups
g
# Out:
# {'A': [0, 1, 4, 5, 8, 9], 'B': [2, 6], 'C': [3], 'D': [7]}

# %%
# to create a dataframe from the group use something like
grpby.get_group("A")
# Out:
#   colA colB      colC      colD
# 0    A    1 -0.917516  0.371238
# 1    A    2  0.728666  0.823692
# 4    A    5  1.274853 -0.222768
# 5    A    6 -0.701205  0.059788
# 8    A    9  0.336358  2.087440
# 9    A    0  1.525196 -0.970353

# %% [markdown]
# ### Find all the groups

# %%
# but we may not know all the groups in the dataframe.
# so got to find a way to list all groups as dataframes.
#
# some basic python helps create a list of groupby names
grpby_labels_list = [*g.keys()]  # using the unpacking operator *
# alternatively
# grpby_labels_list = list(g.keys())
grpby_labels_list
# Out:
# ['A', 'B', 'C', 'D']

# %%
# create a dict where the group label is the key and the group dataframe is the value
grps = {lbl: grpby.get_group(lbl) for lbl in grpby_labels_list}

# now use the dict to access individual dataframes created out of the groupby operation
grps["B"]

# question: can we create a dataframe of dataframes?
# Out:
#   colA colB      colC      colD
# 2    B    3 -1.223632  0.563674
# 6    B    7 -0.487083  0.194251

# %%
# You can see the datatype of the value is a pandas dataframe
type(grps["A"])
# Out:
# pandas.core.frame.DataFrame

# %%
# make a function of it all...
def get_all_groups(df_grpby):
    return {lbl: df_grpby.get_group(lbl) for lbl in list(df_grpby.groups.keys())}

# %%
grps = get_all_groups(grp_df.groupby("colA"))
grps
# Out:
# {'A':   colA colB      colC      colD
#  0    A    1 -0.917516  0.371238
#  1    A    2  0.728666  0.823692
#  4    A    5  1.274853 -0.222768
#  5    A    6 -0.701205  0.059788
#  8    A    9  0.336358  2.087440
#  9    A    0  1.525196 -0.970353,
#  'B':   colA colB      colC      colD
#  2    B    3 -1.223632  0.563674
#  6    B    7 -0.487083  0.194251,
#  'C':   colA colB      colC      colD
#  3    C    4 -0.042648 -0.109007,
#  'D':   colA colB      colC      colD
#  7    D    8 -1.254922  0.239682}

# %%
# get a sum of values from each group
grp_df.groupby("colA").sum()
# Out:
#         colB      colC      colD
# colA
# A     125690  2.246353  2.149036
# B         37 -1.710715  0.757926
# C          4 -0.042648 -0.109007
# D          8 -1.254922  0.239682

# %%
# let's add one more column to the dataframe
# we can try grouping on two columns
grp_df["colE"] = list("1231231231")
grp_df
# Out:
#   colA colB      colC      colD colE
# 0    A    1 -0.917516  0.371238    1
# 1    A    2  0.728666  0.823692    2
# 2    B    3 -1.223632  0.563674    3
# 3    C    4 -0.042648 -0.109007    1
# 4    A    5  1.274853 -0.222768    2
# 5    A    6 -0.701205  0.059788    3
# 6    B    7 -0.487083  0.194251    1
# 7    D    8 -1.254922  0.239682    2
# 8    A    9  0.336358  2.087440    3
# 9    A    0  1.525196 -0.970353    1

# %%
g2 = grp_df.groupby(["colA", "colE"])
grps2 = get_all_groups(g2)
grps2
# Out:
# {('A',
#   '1'):   colA colB      colC      colD colE
#  0    A    1 -0.917516  0.371238    1
#  9    A    0  1.525196 -0.970353    1,
#  ('A',
#   '2'):   colA colB      colC      colD colE
#  1    A    2  0.728666  0.823692    2
#  4    A    5  1.274853 -0.222768    2,
#  ('A',
#   '3'):   colA colB      colC      colD colE
#  5    A    6 -0.701205  0.059788    3
#  8    A    9  0.336358  2.087440    3,
#  ('B',
#   '1'):   colA colB      colC      colD colE
#  6    B    7 -0.487083  0.194251    1,
#  ('B',
#   '3'):   colA colB      colC      colD colE
#  2    B    3 -1.223632  0.563674    3,
#  ('C',
#   '1'):   colA colB      colC      colD colE
#  3    C    4 -0.042648 -0.109007    1,
#  ('D',
#   '2'):   colA colB      colC      colD colE
#  7    D    8 -1.254922  0.239682    2}

# %%
render_df_side_by_side(grps2[("A", "1")], grps2[("A", "2")], "A,1", "A,2")
# Out:
# <style type="text/css">
# </style>
# <table id="T_51076" style='display:inline'>
#   <caption>A,1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51076_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_51076_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_51076_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_51076_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_51076_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51076_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51076_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_51076_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_51076_row0_col2" class="data row0 col2" >-0.917516</td>
#       <td id="T_51076_row0_col3" class="data row0 col3" >0.371238</td>
#       <td id="T_51076_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_51076_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_51076_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_51076_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_51076_row1_col2" class="data row1 col2" >1.525196</td>
#       <td id="T_51076_row1_col3" class="data row1 col3" >-0.970353</td>
#       <td id="T_51076_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d41ec" style='display:inline'>
#   <caption>A,2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d41ec_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_d41ec_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_d41ec_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_d41ec_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_d41ec_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d41ec_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_d41ec_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_d41ec_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_d41ec_row0_col2" class="data row0 col2" >0.728666</td>
#       <td id="T_d41ec_row0_col3" class="data row0 col3" >0.823692</td>
#       <td id="T_d41ec_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_d41ec_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_d41ec_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_d41ec_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_d41ec_row1_col2" class="data row1 col2" >1.274853</td>
#       <td id="T_d41ec_row1_col3" class="data row1 col3" >-0.222768</td>
#       <td id="T_d41ec_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Reshaping
#
# Stacking and Pivot Tables.
# This really warrants more practice, at least go through [the page](https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html#)

# %% [markdown]
# ## Stacking

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)

# %% [markdown]
# If the syntax [*expression](https://docs.python.org/dev/reference/expressions.html#calls) appears in the function call, expression must evaluate to an iterable. Elements from these iterables are treated as if they were additional positional arguments.
#
# ...although the *expression syntax may appear after explicit keyword arguments, it is processed before the keyword arguments (and any **expression arguments)

# %%
# starred expressions...
def f(a, b):
    print(a, " ", b)


f(
    b=1, *(2,)
)  # works, the tuple (iterable) is expanded, 2 is assigned to a, then b fills the next argument slot
# f (a=1, *(2,)) # FAILS, multiple values for argument 'a'
# Out:
# 2   1

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
stack_idx = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])

# %%
stack_df = pd.DataFrame(np.random.randn(8, 2), index=stack_idx, columns=["a", "b"])
stack_df
# Out:
#                      a         b
# first second
# bar   one    -1.569116  0.417175
#       two     0.205407  0.373984
# baz   one     0.931429 -1.780329
#       two     0.213578  0.399523
# foo   one     1.019377  0.252729
#       two    -0.038853  0.501629
# qux   one    -2.224998 -0.019240
#       two    -1.789701  0.408075

# %%
# stack really just combines the columns
stacked = stack_df.stack()
stacked
# Out:
# first  second
# bar    one     a   -1.569116
#                b    0.417175
#        two     a    0.205407
#                b    0.373984
# baz    one     a    0.931429
#                b   -1.780329
#        two     a    0.213578
#                b    0.399523
# foo    one     a    1.019377
#                b    0.252729
#        two     a   -0.038853
#                b    0.501629
# qux    one     a   -2.224998
#                b   -0.019240
#        two     a   -1.789701
#                b    0.408075
# dtype: float64

# %%
# unstacked brings back the two columns
# by default unstacks the last level
unstacked = stacked.unstack()
unstacked
# Out:
#                      a         b
# first second
# bar   one    -1.569116  0.417175
#       two     0.205407  0.373984
# baz   one     0.931429 -1.780329
#       two     0.213578  0.399523
# foo   one     1.019377  0.252729
#       two    -0.038853  0.501629
# qux   one    -2.224998 -0.019240
#       two    -1.789701  0.408075

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   a -1.569116  0.205407
#       b  0.417175  0.373984
# baz   a  0.931429  0.213578
#       b -1.780329  0.399523
# foo   a  1.019377 -0.038853
#       b  0.252729  0.501629
# qux   a -2.224998 -1.789701
#       b -0.019240  0.408075

# %%
stacked.unstack(0)
# Out:
# first          bar       baz       foo       qux
# second
# one    a -1.569116  0.931429  1.019377 -2.224998
#        b  0.417175 -1.780329  0.252729 -0.019240
# two    a  0.205407  0.213578 -0.038853 -1.789701
#        b  0.373984  0.399523  0.501629  0.408075

# %%
# you can basically pivot the columns and rows using a combination of stack() and unstack()
unstacked.unstack()
# Out:
#                a                   b
# second       one       two       one       two
# first
# bar    -1.569116  0.205407  0.417175  0.373984
# baz     0.931429  0.213578 -1.780329  0.399523
# foo     1.019377 -0.038853  0.252729  0.501629
# qux    -2.224998 -1.789701 -0.019240  0.408075

# %% [markdown]
# ## Pivot Tables

# %%
# we're now just using data created in the pandas documentation - just cause, time.
pivot_tables_df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
pivot_tables_df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.075034  0.951973
# 1     one  B  foo -1.365650 -1.326740
# 2     two  C  foo -1.000317  0.126081
# 3   three  A  bar -1.557018 -0.823072
# 4     one  B  bar -0.717401 -0.980407
# 5     one  C  bar  0.372764  0.991359
# 6     two  A  foo -1.225971 -2.494427
# 7   three  B  foo -1.383177  0.889015
# 8     one  C  foo -0.793209  0.234141
# 9     one  A  bar  0.535059  0.668283
# 10    two  B  bar -1.666599  0.163312
# 11  three  C  bar -0.880131 -0.244029

# %%
# simple pivot tables - data, values to aggregate, index, columns to pivot along
pd.pivot_table(pivot_tables_df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.535059 -0.075034
#       B -0.717401 -1.365650
#       C  0.372764 -0.793209
# three A -1.557018       NaN
#       B       NaN -1.383177
#       C -0.880131       NaN
# two   A       NaN -1.225971
#       B -1.666599       NaN
#       C       NaN -1.000317

# %%
# more'n one columns of values
# mark all NaN as zero (0)
pd.pivot_table(
    pivot_tables_df, values=["D", "E"], index=["A", "B"], columns=["C"]
).fillna(0)
# Out:
#                 D                   E
# C             bar       foo       bar       foo
# A     B
# one   A  0.535059 -0.075034  0.668283  0.951973
#       B -0.717401 -1.365650 -0.980407 -1.326740
#       C  0.372764 -0.793209  0.991359  0.234141
# three A -1.557018  0.000000 -0.823072  0.000000
#       B  0.000000 -1.383177  0.000000  0.889015
#       C -0.880131  0.000000 -0.244029  0.000000
# two   A  0.000000 -1.225971  0.000000 -2.494427
#       B -1.666599  0.000000  0.163312  0.000000
#       C  0.000000 -1.000317  0.000000  0.126081

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Resample
# We may need to resample data to a different time-frequency.
# Like get data every second and resample to data every 5 minutes and so on...

# %%
rng = pd.date_range("01/01/2022", periods=1000, freq="S")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample("5min").sum()
# Out:
# 2022-01-01 00:00:00    74272
# 2022-01-01 00:05:00    71742
# 2022-01-01 00:10:00    73105
# 2022-01-01 00:15:00    25507
# Freq: 5T, dtype: int64

# %% [markdown]
# read up on [date offset strings](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects) like '5min' etc.

# %% [markdown]
# ## Timezones

# %%
# timezone representation
rng2 = pd.date_range("01/01/2022", periods=500, freq="D")
ts2 = pd.Series(np.random.randint(0, 365, len(rng2)), index=rng2)
ts2_utc = ts2.tz_localize("UTC")

# %%
# convert to US/Eastern
ts2_utc.tz_convert("US/Eastern")
# Out:
# 2021-12-31 19:00:00-05:00     55
# 2022-01-01 19:00:00-05:00    193
# 2022-01-02 19:00:00-05:00    181
# 2022-01-03 19:00:00-05:00    354
# 2022-01-04 19:00:00-05:00     95
#                             ...
# 2023-05-10 20:00:00-04:00     72
# 2023-05-11 20:00:00-04:00    155
# 2023-05-12 20:00:00-04:00     39
# 2023-05-13 20:00:00-04:00    236
# 2023-05-14 20:00:00-04:00    212
# Freq: D, Length: 500, dtype: int64

# %% [markdown]
# ## Time span representations
#
# Converting between periods and timestamps.
#
# Period is a _timespan_ - span of time between two timestamps.

# %%
# month - end of each
rng3 = pd.date_range("01/01/2022", periods=12, freq="M")
rng3
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts3 = pd.Series(np.random.randn(len(rng3)), index=rng3)
ts3
# Out:
# 2022-01-31    0.098827
# 2022-02-28    0.083582
# 2022-03-31   -1.007415
# 2022-04-30    0.786591
# 2022-05-31   -0.163765
# 2022-06-30    0.605526
# 2022-07-31   -0.802065
# 2022-08-31    0.103782
# 2022-09-30    1.338962
# 2022-10-31   -0.090781
# 2022-11-30    0.048555
# 2022-12-31    0.136162
# Freq: M, dtype: float64

# %%
ps = ts3.to_period()
ps
# Out:
# 2022-01    0.098827
# 2022-02    0.083582
# 2022-03   -1.007415
# 2022-04    0.786591
# 2022-05   -0.163765
# 2022-06    0.605526
# 2022-07   -0.802065
# 2022-08    0.103782
# 2022-09    1.338962
# 2022-10   -0.090781
# 2022-11    0.048555
# 2022-12    0.136162
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2022-01-01    0.098827
# 2022-02-01    0.083582
# 2022-03-01   -1.007415
# 2022-04-01    0.786591
# 2022-05-01   -0.163765
# 2022-06-01    0.605526
# 2022-07-01   -0.802065
# 2022-08-01    0.103782
# 2022-09-01    1.338962
# 2022-10-01   -0.090781
# 2022-11-01    0.048555
# 2022-12-01    0.136162
# Freq: MS, dtype: float64

# %% [markdown]
# A more complex use-case:
# convert a _quarterly frequency_ with _year ending in November_ to _9am_ of _the end of the month_ _following_ the _quarter end_

# %%
prng = pd.period_range("1990Q1", "2022Q4", freq="Q-NOV")
type(prng)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
ts4 = pd.Series(np.random.randn(len(prng)), index=prng)
ts4.head()
# Out:
# 1990Q1    0.217424
# 1990Q2    0.104070
# 1990Q3   -0.328954
# 1990Q4    0.441217
# 1991Q1   -0.554199
# Freq: Q-NOV, dtype: float64

# %%
ts4.index = (prng.asfreq("M", "e") + 1).asfreq("H", "s") + 9
ts4.head()
# Out:
# 1990-03-01 09:00    0.217424
# 1990-06-01 09:00    0.104070
# 1990-09-01 09:00   -0.328954
# 1990-12-01 09:00    0.441217
# 1991-03-01 09:00   -0.554199
# Freq: H, dtype: float64

# %% [markdown]
# # Categoricals
#
# [This page](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html#categorical-data).
#
# ##### Note: With v2.0+ some of these are breaking - so this sections needs an update.
#
# See [this issue on GitHub](https://github.com/pandas-dev/pandas/issues/52593)
#
# For e.g., gender, social class, blood type, country affiliation, observation time or rating via Likert scales.
#
# Categorical data. Categories allow (usually) fixed number of possible values. Categorical data may have some order, but not support numerical operations (for e.g., 'strongly agree', 'agree', 'disagree', 'strongly disagree').

# %%
cat_df = pd.DataFrame({"id": list("123456"), "raw_grade": list("abbaae")})
cat_df
# Out:
#   id raw_grade
# 0  1         a
# 1  2         b
# 2  3         b
# 3  4         a
# 4  5         a
# 5  6         e

# %%
# convert the raw_grade col to categories
cat_df["grade"] = cat_df["raw_grade"].astype("category")
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
cat_df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
# this breaks with v2.0+
# [TODO] Find a fix

# can give more meaningful names here
# direct assignment to Series.cat.categories()
# cat_df["grade"].cat.categories = ["very good", "meh", "very bad"]
# cat_df["grade"]

# %%
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
list(cat_df["grade"].cat.categories)

# categorical.CategoricalAccessor encapsulates all changes to categoricals
# for e.g., set_categories or remove_categories
# dir(cat_df['grade'].cat)
# Out:
# ['a', 'b', 'e']

# %%
# add more categories
cat_df["grade"] = cat_df["grade"].cat.set_categories(
    ["very bad", "bad", "meh", "good", "very good"]
)
# new list of categories
list(cat_df["grade"].cat.categories)
# Out:
# ['very bad', 'bad', 'meh', 'good', 'very good']

# %%
# now when we can sort the dataframe in order of categories (not lexical)
sorted_cat_df = cat_df.sort_values(by="grade")
render_df_side_by_side(cat_df, sorted_cat_df, "OG", "Sorted")
# Out:
# <style type="text/css">
# </style>
# <table id="T_a5a68" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5a68_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_a5a68_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_a5a68_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5a68_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5a68_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a5a68_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_a5a68_row0_col2" class="data row0 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a5a68_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5a68_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_a5a68_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_a5a68_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a5a68_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5a68_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a5a68_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_a5a68_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a5a68_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a5a68_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_a5a68_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_a5a68_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a5a68_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a5a68_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_a5a68_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_a5a68_row4_col2" class="data row4 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a5a68_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a5a68_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_a5a68_row5_col1" class="data row5 col1" >e</td>
#       <td id="T_a5a68_row5_col2" class="data row5 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_9d9b8" style='display:inline'>
#   <caption>Sorted</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d9b8_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_9d9b8_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_9d9b8_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d9b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d9b8_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_9d9b8_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_9d9b8_row0_col2" class="data row0 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9d9b8_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_9d9b8_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_9d9b8_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9d9b8_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_9d9b8_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_9d9b8_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9d9b8_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_9d9b8_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_9d9b8_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9d9b8_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_9d9b8_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_9d9b8_row4_col2" class="data row4 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9d9b8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9d9b8_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_9d9b8_row5_col1" class="data row5 col1" >e</td>
#       <td id="T_9d9b8_row5_col2" class="data row5 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# grouping
# cat_grp = cat_df.groupby("grade")
# cat_grp.get_group("very good")

# %%
# count elements
# cat_grp.size()
