# %% [markdown]
# # Setup
#
# This is following [10 minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html) for Pandas (v 2.x.x, as of this writing) but may take a little more than 10 minutes to finish. Lot's of small changes, references etc. The original notebook was downloaded from
# [this repo on github](https://github.com/shauryashaurya/learn-data-munging/blob/main/02-Pandas/01.01-10%2B-minutes-to-Pandas.ipynb).

# %% [markdown]
# You can also open this notebook in Google Colab
#
# <a href="https://colab.research.google.com/github/shauryashaurya/learn-data-munging/blob/main/02-Pandas/01.01-10%2B-minutes-to-Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.26.0'

# %%
pd.__version__
# Out:
# '2.1.2'

# %% [markdown]
# # Object creation

# %%
# Series - pass a list to pd.Series
s1 = pd.Series([1, 2, 3, np.nan, 5])

# %%
s1
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# dtype: float64

# %%
# create an index to use in the dataframe
# default frequency is D (day), so creates a DatetimeIndex of 10 days
dates = pd.date_range("20220619", periods=10)
dates
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# just in case you are wondering, here's [all the "offset aliases"](https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases) for Datetime

# %%
# Dataframe - pass a Numpy array
# create a 10 row, 4 col random number array, index by dates, give some column names
df = pd.DataFrame(np.random.randn(10, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546
# 2022-06-22  1.536870  0.180747  0.121895  0.892899
# 2022-06-23 -0.051249 -1.583298  0.394773 -0.310881
# 2022-06-24  0.038414 -1.251971  0.670493  0.205204
# 2022-06-25 -1.025068  0.067278  0.962100  0.414161
# 2022-06-26 -0.545829 -0.908608  0.341681  1.503387
# 2022-06-27 -0.733098 -0.096156 -1.398009  0.617913
# 2022-06-28  0.656146  0.521780  0.480596  1.009676

# %%
# Create a dataframe by passing a dictionary of objects
# where each object can be converted into a series-like structure
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20220619"),
        "C": pd.Series(1, index=list(range(6)), dtype="float32"),
        "D": np.array([3] * 6, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train", "test", "train"]),
        "F": list("foofoo"),
        "G": "foo",
    }
)

df2
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %%
# the datatype of each of the columns would be different
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# G           object
# dtype: object

# %% [markdown]
# # Viewing Data

# %%
# top of the dataframe
df.head()
# Out:
#                    A         B         C         D
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546
# 2022-06-22  1.536870  0.180747  0.121895  0.892899
# 2022-06-23 -0.051249 -1.583298  0.394773 -0.310881

# %%
# bottom 3 records of the dataframe
df.tail(3)
# Out:
#                    A         B         C         D
# 2022-06-26 -0.545829 -0.908608  0.341681  1.503387
# 2022-06-27 -0.733098 -0.096156 -1.398009  0.617913
# 2022-06-28  0.656146  0.521780  0.480596  1.009676

# %%
# index of the df
df.index
# Out:
# DatetimeIndex(['2022-06-19', '2022-06-20', '2022-06-21', '2022-06-22',
#                '2022-06-23', '2022-06-24', '2022-06-25', '2022-06-26',
#                '2022-06-27', '2022-06-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
# columns of the df
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# .to_numpy gives a NumPy representation of the dataframe
# this is expensive if all columns are of different data type
# NumPy arrays support a single data type
# so with mixed data types, the data type of
# each element is
df.to_numpy()
# Out:
# array([[ 1.04134105, -1.0636319 , -1.51385179, -0.31744598],
#        [ 0.15854477,  0.5846162 , -1.21989932,  0.9129922 ],
#        [ 0.7330026 , -0.18838423,  2.01609044, -0.72254589],
#        [ 1.53687042,  0.18074696,  0.12189483,  0.89289902],
#        [-0.05124892, -1.58329752,  0.39477315, -0.31088077],
#        [ 0.03841432, -1.2519713 ,  0.67049342,  0.20520365],
#        [-1.02506764,  0.06727765,  0.96210007,  0.41416137],
#        [-0.54582855, -0.9086084 ,  0.3416815 ,  1.50338692],
#        [-0.73309847, -0.09615586, -1.39800893,  0.61791298],
#        [ 0.65614556,  0.52178049,  0.4805958 ,  1.00967567]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'f',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'test', 'o',
#         'foo'],
#        [1.0, Timestamp('2022-06-19 00:00:00'), 1.0, 3, 'train', 'o',
#         'foo']], dtype=object)

# %%
# quick summary stats
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.180908  -0.373763   0.085587   0.420536
# std     0.816651   0.769568   1.136237   0.703711
# min    -1.025068  -1.583298  -1.513852  -0.722546
# 25%    -0.422184  -1.024876  -0.884451  -0.181860
# 50%     0.098480  -0.142270   0.368227   0.516037
# 75%     0.713788   0.152380   0.623019   0.907969
# max     1.536870   0.584616   2.016090   1.503387

# %% [markdown]
# 1. **count** = Count number of non-NA/null observations
# 1. **max** = Maximum of the values in the object
# 1. **min** = Minimum of the values in the object
# 1. **mean** = Mean of the values
# 1. **std** = Standard deviation of the observations
# 1. **25%** = Default lower percentile
# 1. **50%** = 50 percentile - same as the median
# 1. **75%** = Default upper percentile

# %%
# change the percentiles
df.describe(percentiles=[0.1, 0.5, 0.9])
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.180908  -0.373763   0.085587   0.420536
# std     0.816651   0.769568   1.136237   0.703711
# min    -1.025068  -1.583298  -1.513852  -0.722546
# 10%    -0.762295  -1.285104  -1.409593  -0.357956
# 50%     0.098480  -0.142270   0.368227   0.516037
# 90%     1.090894   0.528064   1.067499   1.059047
# max     1.536870   0.584616   2.016090   1.503387

# %%
# E, F, G in d2 are not numeric, so do not come up in describe()
df2.describe()
# Out:
#          A                    B    C    D
# count  6.0                    6  6.0  6.0
# mean   1.0  2022-06-19 00:00:00  1.0  3.0
# min    1.0  2022-06-19 00:00:00  1.0  3.0
# 25%    1.0  2022-06-19 00:00:00  1.0  3.0
# 50%    1.0  2022-06-19 00:00:00  1.0  3.0
# 75%    1.0  2022-06-19 00:00:00  1.0  3.0
# max    1.0  2022-06-19 00:00:00  1.0  3.0
# std    0.0                  NaN  0.0  0.0

# %%
# transpose the data
# turn rows to columns and vice versa
df.T
# Out:
#    2022-06-19  2022-06-20  2022-06-21  2022-06-22  2022-06-23  2022-06-24  \
# A    1.041341    0.158545    0.733003    1.536870   -0.051249    0.038414
# B   -1.063632    0.584616   -0.188384    0.180747   -1.583298   -1.251971
# C   -1.513852   -1.219899    2.016090    0.121895    0.394773    0.670493
# D   -0.317446    0.912992   -0.722546    0.892899   -0.310881    0.205204
#
#    2022-06-25  2022-06-26  2022-06-27  2022-06-28
# A   -1.025068   -0.545829   -0.733098    0.656146
# B    0.067278   -0.908608   -0.096156    0.521780
# C    0.962100    0.341681   -1.398009    0.480596
# D    0.414161    1.503387    0.617913    1.009676

# %% [markdown]
# ### [Axis in pandas](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_axis.html?highlight=set_ax#pandas.DataFrame.set_axis)
#
# ```axis{0 or ‘index’, 1 or ‘columns’}```
#
# Always remember that when you specify:
# * ```axis=0``` or ```axis='index'``` you indicate that the operation should be along the _index_ (aka across the rows). More often than not indexes will go from top to bottom (vertically), but sometimes they may not (for e.g. if you use columns as index or when you have hierarchical or multi-index data).
# * ```axis=1``` or ```axis='columns'``` indicates the operation is along the columns
#
# When in doubt use the explicit version ```'index'``` or ```'columns'``` instead of ```0``` or ```1```

# %%
# sort along the axis - 1 = horizontal
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2022-06-19 -0.317446 -1.513852 -1.063632  1.041341
# 2022-06-20  0.912992 -1.219899  0.584616  0.158545
# 2022-06-21 -0.722546  2.016090 -0.188384  0.733003
# 2022-06-22  0.892899  0.121895  0.180747  1.536870
# 2022-06-23 -0.310881  0.394773 -1.583298 -0.051249
# 2022-06-24  0.205204  0.670493 -1.251971  0.038414
# 2022-06-25  0.414161  0.962100  0.067278 -1.025068
# 2022-06-26  1.503387  0.341681 -0.908608 -0.545829
# 2022-06-27  0.617913 -1.398009 -0.096156 -0.733098
# 2022-06-28  1.009676  0.480596  0.521780  0.656146

# %%
# sort along the axis - 0 = vertical
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2022-06-28  0.656146  0.521780  0.480596  1.009676
# 2022-06-27 -0.733098 -0.096156 -1.398009  0.617913
# 2022-06-26 -0.545829 -0.908608  0.341681  1.503387
# 2022-06-25 -1.025068  0.067278  0.962100  0.414161
# 2022-06-24  0.038414 -1.251971  0.670493  0.205204
# 2022-06-23 -0.051249 -1.583298  0.394773 -0.310881
# 2022-06-22  1.536870  0.180747  0.121895  0.892899
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446

# %%
# sort ascending by values in a column
df.sort_values(by="A")
# Out:
#                    A         B         C         D
# 2022-06-25 -1.025068  0.067278  0.962100  0.414161
# 2022-06-27 -0.733098 -0.096156 -1.398009  0.617913
# 2022-06-26 -0.545829 -0.908608  0.341681  1.503387
# 2022-06-23 -0.051249 -1.583298  0.394773 -0.310881
# 2022-06-24  0.038414 -1.251971  0.670493  0.205204
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992
# 2022-06-28  0.656146  0.521780  0.480596  1.009676
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446
# 2022-06-22  1.536870  0.180747  0.121895  0.892899

# %%
# sort by non-numerical values
df2.sort_values(by="F", ascending=False)
# Out:
#      A          B    C  D      E  F    G
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo

# %%
# sort by two or more columns
df2.sort_values(by=["F", "E"])
# Out:
#      A          B    C  D      E  F    G
# 0  1.0 2022-06-19  1.0  3   test  f  foo
# 3  1.0 2022-06-19  1.0  3  train  f  foo
# 2  1.0 2022-06-19  1.0  3   test  o  foo
# 4  1.0 2022-06-19  1.0  3   test  o  foo
# 1  1.0 2022-06-19  1.0  3  train  o  foo
# 5  1.0 2022-06-19  1.0  3  train  o  foo

# %% [markdown]
# # Selection

# %% [markdown]
# For production prefer the following instead of other data access methods (typical python methods like ["col"] or [a:b] slices etc.):
#
# ```.at, .iat, .loc and .iloc.```

# %% [markdown]
# ## Getting

# %%
# selecting a single column returns a Series object
df["A"]
# Out:
# 2022-06-19    1.041341
# 2022-06-20    0.158545
# 2022-06-21    0.733003
# 2022-06-22    1.536870
# 2022-06-23   -0.051249
# 2022-06-24    0.038414
# 2022-06-25   -1.025068
# 2022-06-26   -0.545829
# 2022-06-27   -0.733098
# 2022-06-28    0.656146
# Freq: D, Name: A, dtype: float64

# %%
# selecting a slice
df[1:5]
# Out:
#                    A         B         C         D
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546
# 2022-06-22  1.536870  0.180747  0.121895  0.892899
# 2022-06-23 -0.051249 -1.583298  0.394773 -0.310881

# %% [markdown]
# ## Selection by label

# %%
# selecting based on a label
df.loc[dates[0]]
# Out:
# A    1.041341
# B   -1.063632
# C   -1.513852
# D   -0.317446
# Name: 2022-06-19 00:00:00, dtype: float64

# %%
# select on a multi-axis by lable
# I honestly do not know what the comment above means...help!
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2022-06-19  1.041341 -1.063632
# 2022-06-20  0.158545  0.584616
# 2022-06-21  0.733003 -0.188384
# 2022-06-22  1.536870  0.180747
# 2022-06-23 -0.051249 -1.583298
# 2022-06-24  0.038414 -1.251971
# 2022-06-25 -1.025068  0.067278
# 2022-06-26 -0.545829 -0.908608
# 2022-06-27 -0.733098 -0.096156
# 2022-06-28  0.656146  0.521780

# %%
# specific index value results in reduction of dimensions
res = df.loc["2022-06-20"]
print(res)
print("res.shape = ", res.shape, " vs. df.shape = ", df.shape)
# Out:
# A    0.158545
# B    0.584616
# C   -1.219899
# D    0.912992
# Name: 2022-06-20 00:00:00, dtype: float64
# res.shape =  (4,)  vs. df.shape =  (10, 4)

# %%
# get to a specific scalar:
#
# method one
df.loc[dates[0], "A"]
# Out:
# 1.041341047979811

# %%
#
# method two (slightly faster than method one)
df.at[dates[0], "A"]
# Out:
# 1.041341047979811

# %% [markdown]
# ## Selection by position

# %%
df.iloc[2]
# Out:
# A    0.733003
# B   -0.188384
# C    2.016090
# D   -0.722546
# Name: 2022-06-21 00:00:00, dtype: float64

# %%
# slices - similar to NumPy / Python - [row:slice, col:slice]
df.iloc[1:5, 0:2]
# Out:
#                    A         B
# 2022-06-20  0.158545  0.584616
# 2022-06-21  0.733003 -0.188384
# 2022-06-22  1.536870  0.180747
# 2022-06-23 -0.051249 -1.583298

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
df.iloc[[0, 1, 2, 6], [0, 2]]
# Out:
#                    A         C
# 2022-06-19  1.041341 -1.513852
# 2022-06-20  0.158545 -1.219899
# 2022-06-21  0.733003  2.016090
# 2022-06-25 -1.025068  0.962100

# %%
# by list of locations - similar to NumPy / Python - [[list of rows], [list of cols]]
# change the order of columns, repeact a column
df.iloc[[0, 1, 2, 6], [2, 1, 0, 2]]
# Out:
#                    C         B         A         C
# 2022-06-19 -1.513852 -1.063632  1.041341 -1.513852
# 2022-06-20 -1.219899  0.584616  0.158545 -1.219899
# 2022-06-21  2.016090 -0.188384  0.733003  2.016090
# 2022-06-25  0.962100  0.067278 -1.025068  0.962100

# %%
# slice rows explicitly, keep all columns
df.iloc[[1, 2], :]
# Out:
#                    A         B         C         D
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546

# %%
# slice columns, keep all rows
df.iloc[:, [2, 3]]
# Out:
#                    C         D
# 2022-06-19 -1.513852 -0.317446
# 2022-06-20 -1.219899  0.912992
# 2022-06-21  2.016090 -0.722546
# 2022-06-22  0.121895  0.892899
# 2022-06-23  0.394773 -0.310881
# 2022-06-24  0.670493  0.205204
# 2022-06-25  0.962100  0.414161
# 2022-06-26  0.341681  1.503387
# 2022-06-27 -1.398009  0.617913
# 2022-06-28  0.480596  1.009676

# %%
# everything, because you can
df.iloc[:, :]
# Out:
#                    A         B         C         D
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546
# 2022-06-22  1.536870  0.180747  0.121895  0.892899
# 2022-06-23 -0.051249 -1.583298  0.394773 -0.310881
# 2022-06-24  0.038414 -1.251971  0.670493  0.205204
# 2022-06-25 -1.025068  0.067278  0.962100  0.414161
# 2022-06-26 -0.545829 -0.908608  0.341681  1.503387
# 2022-06-27 -0.733098 -0.096156 -1.398009  0.617913
# 2022-06-28  0.656146  0.521780  0.480596  1.009676

# %%
# get to a scalar (2 methods, just like before)
#
# method one: use iloc
df.iloc[1, 2]
# Out:
# -1.2198993201885437

# %%
#
# method two: use iat
df.iat[1, 2]
# Out:
# -1.2198993201885437

# %% [markdown]
# ## Boolean Indexing

# %%
# use a value found in a single col to get data
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546
# 2022-06-22  1.536870  0.180747  0.121895  0.892899
# 2022-06-24  0.038414 -1.251971  0.670493  0.205204
# 2022-06-28  0.656146  0.521780  0.480596  1.009676

# %%
# boolean across the entire DF - vals that don't match go NaN
df[df > 0]
# Out:
#                    A         B         C         D
# 2022-06-19  1.041341       NaN       NaN       NaN
# 2022-06-20  0.158545  0.584616       NaN  0.912992
# 2022-06-21  0.733003       NaN  2.016090       NaN
# 2022-06-22  1.536870  0.180747  0.121895  0.892899
# 2022-06-23       NaN       NaN  0.394773       NaN
# 2022-06-24  0.038414       NaN  0.670493  0.205204
# 2022-06-25       NaN  0.067278  0.962100  0.414161
# 2022-06-26       NaN       NaN  0.341681  1.503387
# 2022-06-27       NaN       NaN       NaN  0.617913
# 2022-06-28  0.656146  0.521780  0.480596  1.009676

# %%
# add another column
df11 = df.copy()
df11["E"] = [
    "one",
    "two",
    "three",
    "four",
    "two",
    "five",
    "one",
    "two",
    "three",
    "four",
]
df11
# Out:
#                    A         B         C         D      E
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446    one
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992    two
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546  three
# 2022-06-22  1.536870  0.180747  0.121895  0.892899   four
# 2022-06-23 -0.051249 -1.583298  0.394773 -0.310881    two
# 2022-06-24  0.038414 -1.251971  0.670493  0.205204   five
# 2022-06-25 -1.025068  0.067278  0.962100  0.414161    one
# 2022-06-26 -0.545829 -0.908608  0.341681  1.503387    two
# 2022-06-27 -0.733098 -0.096156 -1.398009  0.617913  three
# 2022-06-28  0.656146  0.521780  0.480596  1.009676   four

# %%
# the isin() query - basically the in clause
df11[df11["E"].isin(["two", "five"])]
# Out:
#                    A         B         C         D     E
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992   two
# 2022-06-23 -0.051249 -1.583298  0.394773 -0.310881   two
# 2022-06-24  0.038414 -1.251971  0.670493  0.205204  five
# 2022-06-26 -0.545829 -0.908608  0.341681  1.503387   two

# %% [markdown]
# ## Setting values

# %%
# matching indexes auto-aligns values
s1 = pd.Series(range(11, 21), index=pd.date_range("20220619", periods=10))
s1
# Out:
# 2022-06-19    11
# 2022-06-20    12
# 2022-06-21    13
# 2022-06-22    14
# 2022-06-23    15
# 2022-06-24    16
# 2022-06-25    17
# 2022-06-26    18
# 2022-06-27    19
# 2022-06-28    20
# Freq: D, dtype: int64

# %%
df["F"] = s1
df
# Out:
#                    A         B         C         D   F
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446  11
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992  12
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546  13
# 2022-06-22  1.536870  0.180747  0.121895  0.892899  14
# 2022-06-23 -0.051249 -1.583298  0.394773 -0.310881  15
# 2022-06-24  0.038414 -1.251971  0.670493  0.205204  16
# 2022-06-25 -1.025068  0.067278  0.962100  0.414161  17
# 2022-06-26 -0.545829 -0.908608  0.341681  1.503387  18
# 2022-06-27 -0.733098 -0.096156 -1.398009  0.617913  19
# 2022-06-28  0.656146  0.521780  0.480596  1.009676  20

# %%
# setting values by label and position
# first let's make a quick copy
df12 = df.copy()
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446  11
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992  12
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546  13
# 2022-06-22  1.536870  0.180747  0.121895  0.892899  14
# 2022-06-23 -0.051249 -1.583298  0.394773 -0.310881  15
# 2022-06-24  0.038414 -1.251971  0.670493  0.205204  16
# 2022-06-25 -1.025068  0.067278  0.962100  0.414161  17
# 2022-06-26 -0.545829 -0.908608  0.341681  1.503387  18
# 2022-06-27 -0.733098 -0.096156 -1.398009  0.617913  19
# 2022-06-28  0.656146  0.521780  0.480596  1.009676  20

# %%
# set by label
df12.at[dates[0], "A"] = 0
# set by position
df12.iat[0, 1] = 0
df12
# Out:
#                    A         B         C         D   F
# 2022-06-19  0.000000  0.000000 -1.513852 -0.317446  11
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992  12
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546  13
# 2022-06-22  1.536870  0.180747  0.121895  0.892899  14
# 2022-06-23 -0.051249 -1.583298  0.394773 -0.310881  15
# 2022-06-24  0.038414 -1.251971  0.670493  0.205204  16
# 2022-06-25 -1.025068  0.067278  0.962100  0.414161  17
# 2022-06-26 -0.545829 -0.908608  0.341681  1.503387  18
# 2022-06-27 -0.733098 -0.096156 -1.398009  0.617913  19
# 2022-06-28  0.656146  0.521780  0.480596  1.009676  20

# %%
# kinda bigger replacement
df12.loc[:, "D"] = np.array([5] * len(df))
df12
# Out:
#                    A         B         C    D   F
# 2022-06-19  0.000000  0.000000 -1.513852  5.0  11
# 2022-06-20  0.158545  0.584616 -1.219899  5.0  12
# 2022-06-21  0.733003 -0.188384  2.016090  5.0  13
# 2022-06-22  1.536870  0.180747  0.121895  5.0  14
# 2022-06-23 -0.051249 -1.583298  0.394773  5.0  15
# 2022-06-24  0.038414 -1.251971  0.670493  5.0  16
# 2022-06-25 -1.025068  0.067278  0.962100  5.0  17
# 2022-06-26 -0.545829 -0.908608  0.341681  5.0  18
# 2022-06-27 -0.733098 -0.096156 -1.398009  5.0  19
# 2022-06-28  0.656146  0.521780  0.480596  5.0  20

# %%
# setting values using a boolean selection (aka where clause)
df12[df12 > 0] = -df12
df12
# Out:
#                    A         B         C    D   F
# 2022-06-19  0.000000  0.000000 -1.513852 -5.0 -11
# 2022-06-20 -0.158545 -0.584616 -1.219899 -5.0 -12
# 2022-06-21 -0.733003 -0.188384 -2.016090 -5.0 -13
# 2022-06-22 -1.536870 -0.180747 -0.121895 -5.0 -14
# 2022-06-23 -0.051249 -1.583298 -0.394773 -5.0 -15
# 2022-06-24 -0.038414 -1.251971 -0.670493 -5.0 -16
# 2022-06-25 -1.025068 -0.067278 -0.962100 -5.0 -17
# 2022-06-26 -0.545829 -0.908608 -0.341681 -5.0 -18
# 2022-06-27 -0.733098 -0.096156 -1.398009 -5.0 -19
# 2022-06-28 -0.656146 -0.521780 -0.480596 -5.0 -20

# %% [markdown]
# # Missing Data

# %% [markdown]
# ### _reindex_
# change/add/delete index on a specified axis, returns a new dataframe

# %%
df13 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["G"])
df13
# Out:
#                    A         B         C         D   F   G
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446  11 NaN
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992  12 NaN
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546  13 NaN
# 2022-06-22  1.536870  0.180747  0.121895  0.892899  14 NaN

# %% [markdown]
# ### handling missing data
# 1. _```np.nan```_
# 1. _```pandas.isna()```_
# 1. ```df.dropna()```
# 1. ```df.fillna()```

# %%
# missing data in pandas is np.nan
df13.iat[1, 0] = np.nan
df13.iloc[1:, 5] = np.random.randint(1)
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446  11  NaN
# 2022-06-20       NaN  0.584616 -1.219899  0.912992  12  0.0
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546  13  0.0
# 2022-06-22  1.536870  0.180747  0.121895  0.892899  14  0.0

# %%
# get a boolean mask where values are NaN
df131 = pd.isna(df13)
df131
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# or just
pd.isna(df13)
# Out:
#                 A      B      C      D      F      G
# 2022-06-19  False  False  False  False  False   True
# 2022-06-20   True  False  False  False  False  False
# 2022-06-21  False  False  False  False  False  False
# 2022-06-22  False  False  False  False  False  False

# %%
# the original is still there
df13
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446  11  NaN
# 2022-06-20       NaN  0.584616 -1.219899  0.912992  12  0.0
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546  13  0.0
# 2022-06-22  1.536870  0.180747  0.121895  0.892899  14  0.0

# %%
# we are going to drop / replace values now, let's make a couple of copies of the dataframe
df132 = df13.copy()
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446  11  NaN
# 2022-06-20       NaN  0.584616 -1.219899  0.912992  12  0.0
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546  13  0.0
# 2022-06-22  1.536870  0.180747  0.121895  0.892899  14  0.0

# %%
# drop rows/columns that have missing data
# by default it returns a new dataframe, you may want to specify inplace=True for modifying current dataframe:
df_no_na = df132.dropna(how="any")
# how=‘any’ : If any NA values are present, drop that row or column.
# how=‘all’ : If all values are NA, drop that row or column.

# %%
# all rows/cols with missing data stripped
df_no_na
# Out:
#                    A         B         C         D   F    G
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546  13  0.0
# 2022-06-22  1.536870  0.180747  0.121895  0.892899  14  0.0

# %%
# original still intact
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446  11  NaN
# 2022-06-20       NaN  0.584616 -1.219899  0.912992  12  0.0
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546  13  0.0
# 2022-06-22  1.536870  0.180747  0.121895  0.892899  14  0.0

# %%
# drop missing data from original
df132.dropna(how="any", inplace=True)
df132
# Out:
#                    A         B         C         D   F    G
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546  13  0.0
# 2022-06-22  1.536870  0.180747  0.121895  0.892899  14  0.0

# %%
# fill missing data
df133 = df13.copy()
df133.fillna(np.pi * 1000)
# Out:
#                       A         B         C         D   F            G
# 2022-06-19     1.041341 -1.063632 -1.513852 -0.317446  11  3141.592654
# 2022-06-20  3141.592654  0.584616 -1.219899  0.912992  12     0.000000
# 2022-06-21     0.733003 -0.188384  2.016090 -0.722546  13     0.000000
# 2022-06-22     1.536870  0.180747  0.121895  0.892899  14     0.000000

# %% [markdown]
# # Align and Join

# %% [markdown]
# There needs to be a bigger notebook for this topic.
# You need to know there's "joins" in Pandas just like in the SQL world,
# like join and left join and right join and inner and outer and all that...
# Here we'll explore these in the context of the align function - 'aligning' the indexes of two dataframes.
# Later we'll see these again in the context of _merging_ two data frames.

# %% [markdown]
# ## Create two datasets with _mismatched_ indexes

# %%
# date range indexes
idx1 = pd.date_range("2022-01-01", periods=10)
# 2022-01-01', '2022-01-02' don't exist in idx2
# '2022-01-11', '2022-01-12' don't exist in idx1
idx2 = pd.date_range("2022-01-03", periods=10)

# %%
# dataframes from indexes
d1 = pd.DataFrame(
    index=idx1,
    data={"A": np.random.rand(10), "B": np.random.randint(1, high=25, size=10)},
)

d2 = pd.DataFrame(
    index=idx2,
    data={"A": np.random.rand(10), "B": np.random.randint(1, high=25, size=10)},
)

# %% [markdown]
# ## Quick Aside: Rendering two dataframes side-by-side

# %% [markdown]
# The trick of rendering 2 dataframes side-by-side was from [this](https://stackoverflow.com/questions/38783027/jupyter-notebook-display-two-pandas-tables-side-by-side) stackoverflow question.

# %%
# we gon need to display both data frames side by side, so...
from IPython.display import display_html


def render_df_side_by_side(a, b, a_title="", b_title=""):
    a_styler = a.style.set_table_attributes("style='display:inline'").set_caption(
        a_title
    )
    b_styler = b.style.set_table_attributes("style='display:inline'").set_caption(
        b_title
    )
    display_html(a_styler._repr_html_() + b_styler._repr_html_(), raw=True)

# %%
render_df_side_by_side(d1, d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_daeba" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_daeba_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_daeba_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_daeba_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_daeba_row0_col0" class="data row0 col0" >0.436315</td>
#       <td id="T_daeba_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_daeba_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_daeba_row1_col0" class="data row1 col0" >0.107209</td>
#       <td id="T_daeba_row1_col1" class="data row1 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_daeba_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_daeba_row2_col0" class="data row2 col0" >0.306860</td>
#       <td id="T_daeba_row2_col1" class="data row2 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_daeba_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_daeba_row3_col0" class="data row3 col0" >0.556690</td>
#       <td id="T_daeba_row3_col1" class="data row3 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_daeba_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_daeba_row4_col0" class="data row4 col0" >0.236538</td>
#       <td id="T_daeba_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_daeba_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_daeba_row5_col0" class="data row5 col0" >0.507305</td>
#       <td id="T_daeba_row5_col1" class="data row5 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_daeba_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_daeba_row6_col0" class="data row6 col0" >0.869615</td>
#       <td id="T_daeba_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_daeba_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_daeba_row7_col0" class="data row7 col0" >0.963472</td>
#       <td id="T_daeba_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_daeba_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_daeba_row8_col0" class="data row8 col0" >0.955988</td>
#       <td id="T_daeba_row8_col1" class="data row8 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_daeba_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_daeba_row9_col0" class="data row9 col0" >0.752772</td>
#       <td id="T_daeba_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_a21b1" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a21b1_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_a21b1_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a21b1_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_a21b1_row0_col0" class="data row0 col0" >0.643014</td>
#       <td id="T_a21b1_row0_col1" class="data row0 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_a21b1_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_a21b1_row1_col0" class="data row1 col0" >0.088042</td>
#       <td id="T_a21b1_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a21b1_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_a21b1_row2_col0" class="data row2 col0" >0.613500</td>
#       <td id="T_a21b1_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_a21b1_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_a21b1_row3_col0" class="data row3 col0" >0.979507</td>
#       <td id="T_a21b1_row3_col1" class="data row3 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_a21b1_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_a21b1_row4_col0" class="data row4 col0" >0.829249</td>
#       <td id="T_a21b1_row4_col1" class="data row4 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_a21b1_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_a21b1_row5_col0" class="data row5 col0" >0.530647</td>
#       <td id="T_a21b1_row5_col1" class="data row5 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_a21b1_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_a21b1_row6_col0" class="data row6 col0" >0.561214</td>
#       <td id="T_a21b1_row6_col1" class="data row6 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_a21b1_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_a21b1_row7_col0" class="data row7 col0" >0.161999</td>
#       <td id="T_a21b1_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_a21b1_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_a21b1_row8_col0" class="data row8 col0" >0.861839</td>
#       <td id="T_a21b1_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a21b1_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_a21b1_row9_col0" class="data row9 col0" >0.229019</td>
#       <td id="T_a21b1_row9_col1" class="data row9 col1" >13</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Table rendering/styling options is [a bigger discussion](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html#) to be tackled later.

# %% [markdown]
# ## .add, .sub, .mul, .div etc.

# %% [markdown]
# flexible wrappers (```add, sub, mul, div, mod, pow```) to arithmetic operators: ```+, -, *, /, //, %, **```

# %%
# the +, -, *, /, //, %, ** operations align indexes to create a UNION of indexes
d3 = d1 + d2
d4 = d1.sub(d2)  # equivalent to d1-d2
d5 = d1 * d2
d6 = d1.div(d2)

# %%
# indexs not present in the other dataframe get a NaN

# pandas v1.x
# d3.style.highlight_null(null_color='red')

# pandas v2.x+
d3.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_fc9b0_row0_col0, #T_fc9b0_row0_col1, #T_fc9b0_row1_col0, #T_fc9b0_row1_col1, #T_fc9b0_row10_col0, #T_fc9b0_row10_col1, #T_fc9b0_row11_col0, #T_fc9b0_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_fc9b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc9b0_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_fc9b0_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc9b0_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_fc9b0_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_fc9b0_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fc9b0_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_fc9b0_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_fc9b0_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fc9b0_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_fc9b0_row2_col0" class="data row2 col0" >0.949874</td>
#       <td id="T_fc9b0_row2_col1" class="data row2 col1" >37.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9b0_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_fc9b0_row3_col0" class="data row3 col0" >0.644732</td>
#       <td id="T_fc9b0_row3_col1" class="data row3 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9b0_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_fc9b0_row4_col0" class="data row4 col0" >0.850038</td>
#       <td id="T_fc9b0_row4_col1" class="data row4 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9b0_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_fc9b0_row5_col0" class="data row5 col0" >1.486812</td>
#       <td id="T_fc9b0_row5_col1" class="data row5 col1" >32.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9b0_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_fc9b0_row6_col0" class="data row6 col0" >1.698865</td>
#       <td id="T_fc9b0_row6_col1" class="data row6 col1" >46.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9b0_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_fc9b0_row7_col0" class="data row7 col0" >1.494119</td>
#       <td id="T_fc9b0_row7_col1" class="data row7 col1" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9b0_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_fc9b0_row8_col0" class="data row8 col0" >1.517202</td>
#       <td id="T_fc9b0_row8_col1" class="data row8 col1" >36.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9b0_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_fc9b0_row9_col0" class="data row9 col0" >0.914770</td>
#       <td id="T_fc9b0_row9_col1" class="data row9 col1" >8.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fc9b0_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_fc9b0_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_fc9b0_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fc9b0_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_fc9b0_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_fc9b0_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# sub
d4.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_294ed_row0_col0, #T_294ed_row0_col1, #T_294ed_row1_col0, #T_294ed_row1_col1, #T_294ed_row10_col0, #T_294ed_row10_col1, #T_294ed_row11_col0, #T_294ed_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_294ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_294ed_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_294ed_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_294ed_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_294ed_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_294ed_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_294ed_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_294ed_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_294ed_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_294ed_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_294ed_row2_col0" class="data row2 col0" >-0.336154</td>
#       <td id="T_294ed_row2_col1" class="data row2 col1" >-9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_294ed_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_294ed_row3_col0" class="data row3 col0" >0.468647</td>
#       <td id="T_294ed_row3_col1" class="data row3 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_294ed_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_294ed_row4_col0" class="data row4 col0" >-0.376962</td>
#       <td id="T_294ed_row4_col1" class="data row4 col1" >-9.000000</td>
#     </tr>
#     <tr>
#       <th id="T_294ed_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_294ed_row5_col0" class="data row5 col0" >-0.472202</td>
#       <td id="T_294ed_row5_col1" class="data row5 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_294ed_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_294ed_row6_col0" class="data row6 col0" >0.040366</td>
#       <td id="T_294ed_row6_col1" class="data row6 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_294ed_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_294ed_row7_col0" class="data row7 col0" >0.432825</td>
#       <td id="T_294ed_row7_col1" class="data row7 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_294ed_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_294ed_row8_col0" class="data row8 col0" >0.394774</td>
#       <td id="T_294ed_row8_col1" class="data row8 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_294ed_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_294ed_row9_col0" class="data row9 col0" >0.590773</td>
#       <td id="T_294ed_row9_col1" class="data row9 col1" >-4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_294ed_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_294ed_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_294ed_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_294ed_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_294ed_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_294ed_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# mul
d5.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_0122b_row0_col0, #T_0122b_row0_col1, #T_0122b_row1_col0, #T_0122b_row1_col1, #T_0122b_row10_col0, #T_0122b_row10_col1, #T_0122b_row11_col0, #T_0122b_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_0122b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0122b_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_0122b_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0122b_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_0122b_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_0122b_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0122b_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_0122b_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_0122b_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0122b_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_0122b_row2_col0" class="data row2 col0" >0.197315</td>
#       <td id="T_0122b_row2_col1" class="data row2 col1" >322.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0122b_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_0122b_row3_col0" class="data row3 col0" >0.049012</td>
#       <td id="T_0122b_row3_col1" class="data row3 col1" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0122b_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_0122b_row4_col0" class="data row4 col0" >0.145116</td>
#       <td id="T_0122b_row4_col1" class="data row4 col1" >52.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0122b_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_0122b_row5_col0" class="data row5 col0" >0.496909</td>
#       <td id="T_0122b_row5_col1" class="data row5 col1" >255.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0122b_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_0122b_row6_col0" class="data row6 col0" >0.721128</td>
#       <td id="T_0122b_row6_col1" class="data row6 col1" >529.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0122b_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_0122b_row7_col0" class="data row7 col0" >0.511263</td>
#       <td id="T_0122b_row7_col1" class="data row7 col1" >400.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0122b_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_0122b_row8_col0" class="data row8 col0" >0.536514</td>
#       <td id="T_0122b_row8_col1" class="data row8 col1" >324.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0122b_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_0122b_row9_col0" class="data row9 col0" >0.121948</td>
#       <td id="T_0122b_row9_col1" class="data row9 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0122b_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_0122b_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_0122b_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_0122b_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_0122b_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_0122b_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# div
d6.style.highlight_null(color="red")
# Out:
# <style type="text/css">
# #T_fd664_row0_col0, #T_fd664_row0_col1, #T_fd664_row1_col0, #T_fd664_row1_col1, #T_fd664_row10_col0, #T_fd664_row10_col1, #T_fd664_row11_col0, #T_fd664_row11_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_fd664">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd664_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_fd664_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd664_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_fd664_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_fd664_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fd664_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_fd664_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_fd664_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fd664_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_fd664_row2_col0" class="data row2 col0" >0.477221</td>
#       <td id="T_fd664_row2_col1" class="data row2 col1" >0.608696</td>
#     </tr>
#     <tr>
#       <th id="T_fd664_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_fd664_row3_col0" class="data row3 col0" >6.322971</td>
#       <td id="T_fd664_row3_col1" class="data row3 col1" >10.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd664_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_fd664_row4_col0" class="data row4 col0" >0.385555</td>
#       <td id="T_fd664_row4_col1" class="data row4 col1" >0.307692</td>
#     </tr>
#     <tr>
#       <th id="T_fd664_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_fd664_row5_col0" class="data row5 col0" >0.517919</td>
#       <td id="T_fd664_row5_col1" class="data row5 col1" >1.133333</td>
#     </tr>
#     <tr>
#       <th id="T_fd664_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_fd664_row6_col0" class="data row6 col0" >1.048678</td>
#       <td id="T_fd664_row6_col1" class="data row6 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd664_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_fd664_row7_col0" class="data row7 col0" >1.815657</td>
#       <td id="T_fd664_row7_col1" class="data row7 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd664_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_fd664_row8_col0" class="data row8 col0" >1.703429</td>
#       <td id="T_fd664_row8_col1" class="data row8 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd664_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_fd664_row9_col0" class="data row9 col0" >4.646780</td>
#       <td id="T_fd664_row9_col1" class="data row9 col1" >0.333333</td>
#     </tr>
#     <tr>
#       <th id="T_fd664_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_fd664_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_fd664_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_fd664_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_fd664_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_fd664_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### removing the NaN values from the resultant dataframe

# %%
# the + operation is UNION of indexes
d31 = d1 + d2
# indexs not present in the other dataframe get a NaN
# do you can obvs remove nan values like before
d3.dropna().style.highlight_null(color="red")
# Out:
# <style type="text/css">
# </style>
# <table id="T_4936f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4936f_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_4936f_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4936f_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_4936f_row0_col0" class="data row0 col0" >0.949874</td>
#       <td id="T_4936f_row0_col1" class="data row0 col1" >37.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4936f_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_4936f_row1_col0" class="data row1 col0" >0.644732</td>
#       <td id="T_4936f_row1_col1" class="data row1 col1" >22.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4936f_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_4936f_row2_col0" class="data row2 col0" >0.850038</td>
#       <td id="T_4936f_row2_col1" class="data row2 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4936f_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_4936f_row3_col0" class="data row3 col0" >1.486812</td>
#       <td id="T_4936f_row3_col1" class="data row3 col1" >32.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4936f_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_4936f_row4_col0" class="data row4 col0" >1.698865</td>
#       <td id="T_4936f_row4_col1" class="data row4 col1" >46.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4936f_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_4936f_row5_col0" class="data row5 col0" >1.494119</td>
#       <td id="T_4936f_row5_col1" class="data row5 col1" >40.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4936f_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_4936f_row6_col0" class="data row6 col0" >1.517202</td>
#       <td id="T_4936f_row6_col1" class="data row6 col1" >36.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4936f_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_4936f_row7_col0" class="data row7 col0" >0.914770</td>
#       <td id="T_4936f_row7_col1" class="data row7 col1" >8.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## df.align()

# %% [markdown]
# Pandas [align](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.align.html) works to join the dataframes in interesting ways.

# %%
# align returns two dataframes - left and right as a result of a join
# default join is outer - the union of indices will be used as index for left and right
left, right = d1.align(d2, join="outer")
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6bb60" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bb60_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_6bb60_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bb60_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_6bb60_row0_col0" class="data row0 col0" >0.436315</td>
#       <td id="T_6bb60_row0_col1" class="data row0 col1" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bb60_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_6bb60_row1_col0" class="data row1 col0" >0.107209</td>
#       <td id="T_6bb60_row1_col1" class="data row1 col1" >11.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bb60_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_6bb60_row2_col0" class="data row2 col0" >0.306860</td>
#       <td id="T_6bb60_row2_col1" class="data row2 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bb60_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_6bb60_row3_col0" class="data row3 col0" >0.556690</td>
#       <td id="T_6bb60_row3_col1" class="data row3 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bb60_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_6bb60_row4_col0" class="data row4 col0" >0.236538</td>
#       <td id="T_6bb60_row4_col1" class="data row4 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bb60_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_6bb60_row5_col0" class="data row5 col0" >0.507305</td>
#       <td id="T_6bb60_row5_col1" class="data row5 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bb60_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_6bb60_row6_col0" class="data row6 col0" >0.869615</td>
#       <td id="T_6bb60_row6_col1" class="data row6 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bb60_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_6bb60_row7_col0" class="data row7 col0" >0.963472</td>
#       <td id="T_6bb60_row7_col1" class="data row7 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bb60_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_6bb60_row8_col0" class="data row8 col0" >0.955988</td>
#       <td id="T_6bb60_row8_col1" class="data row8 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bb60_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_6bb60_row9_col0" class="data row9 col0" >0.752772</td>
#       <td id="T_6bb60_row9_col1" class="data row9 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bb60_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_6bb60_row10_col0" class="data row10 col0" >nan</td>
#       <td id="T_6bb60_row10_col1" class="data row10 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6bb60_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_6bb60_row11_col0" class="data row11 col0" >nan</td>
#       <td id="T_6bb60_row11_col1" class="data row11 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_d44b3" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d44b3_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_d44b3_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d44b3_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_d44b3_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_d44b3_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d44b3_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_d44b3_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_d44b3_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d44b3_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_d44b3_row2_col0" class="data row2 col0" >0.643014</td>
#       <td id="T_d44b3_row2_col1" class="data row2 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d44b3_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_d44b3_row3_col0" class="data row3 col0" >0.088042</td>
#       <td id="T_d44b3_row3_col1" class="data row3 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d44b3_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_d44b3_row4_col0" class="data row4 col0" >0.613500</td>
#       <td id="T_d44b3_row4_col1" class="data row4 col1" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d44b3_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_d44b3_row5_col0" class="data row5 col0" >0.979507</td>
#       <td id="T_d44b3_row5_col1" class="data row5 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d44b3_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_d44b3_row6_col0" class="data row6 col0" >0.829249</td>
#       <td id="T_d44b3_row6_col1" class="data row6 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d44b3_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_d44b3_row7_col0" class="data row7 col0" >0.530647</td>
#       <td id="T_d44b3_row7_col1" class="data row7 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d44b3_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_d44b3_row8_col0" class="data row8 col0" >0.561214</td>
#       <td id="T_d44b3_row8_col1" class="data row8 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d44b3_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_d44b3_row9_col0" class="data row9 col0" >0.161999</td>
#       <td id="T_d44b3_row9_col1" class="data row9 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d44b3_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_d44b3_row10_col0" class="data row10 col0" >0.861839</td>
#       <td id="T_d44b3_row10_col1" class="data row10 col1" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d44b3_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_d44b3_row11_col0" class="data row11 col0" >0.229019</td>
#       <td id="T_d44b3_row11_col1" class="data row11 col1" >13.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# inner join
left, right = d1.align(d2, join="inner")
render_df_side_by_side(d1, d2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e56d" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e56d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_6e56d_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e56d_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_6e56d_row0_col0" class="data row0 col0" >0.436315</td>
#       <td id="T_6e56d_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6e56d_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_6e56d_row1_col0" class="data row1 col0" >0.107209</td>
#       <td id="T_6e56d_row1_col1" class="data row1 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_6e56d_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_6e56d_row2_col0" class="data row2 col0" >0.306860</td>
#       <td id="T_6e56d_row2_col1" class="data row2 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_6e56d_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_6e56d_row3_col0" class="data row3 col0" >0.556690</td>
#       <td id="T_6e56d_row3_col1" class="data row3 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_6e56d_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_6e56d_row4_col0" class="data row4 col0" >0.236538</td>
#       <td id="T_6e56d_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6e56d_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_6e56d_row5_col0" class="data row5 col0" >0.507305</td>
#       <td id="T_6e56d_row5_col1" class="data row5 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_6e56d_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_6e56d_row6_col0" class="data row6 col0" >0.869615</td>
#       <td id="T_6e56d_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_6e56d_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_6e56d_row7_col0" class="data row7 col0" >0.963472</td>
#       <td id="T_6e56d_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_6e56d_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_6e56d_row8_col0" class="data row8 col0" >0.955988</td>
#       <td id="T_6e56d_row8_col1" class="data row8 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_6e56d_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_6e56d_row9_col0" class="data row9 col0" >0.752772</td>
#       <td id="T_6e56d_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_804f1" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_804f1_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_804f1_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_804f1_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_804f1_row0_col0" class="data row0 col0" >0.643014</td>
#       <td id="T_804f1_row0_col1" class="data row0 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_804f1_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_804f1_row1_col0" class="data row1 col0" >0.088042</td>
#       <td id="T_804f1_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_804f1_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_804f1_row2_col0" class="data row2 col0" >0.613500</td>
#       <td id="T_804f1_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_804f1_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_804f1_row3_col0" class="data row3 col0" >0.979507</td>
#       <td id="T_804f1_row3_col1" class="data row3 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_804f1_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_804f1_row4_col0" class="data row4 col0" >0.829249</td>
#       <td id="T_804f1_row4_col1" class="data row4 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_804f1_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_804f1_row5_col0" class="data row5 col0" >0.530647</td>
#       <td id="T_804f1_row5_col1" class="data row5 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_804f1_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_804f1_row6_col0" class="data row6 col0" >0.561214</td>
#       <td id="T_804f1_row6_col1" class="data row6 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_804f1_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_804f1_row7_col0" class="data row7 col0" >0.161999</td>
#       <td id="T_804f1_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_804f1_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_804f1_row8_col0" class="data row8 col0" >0.861839</td>
#       <td id="T_804f1_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_804f1_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_804f1_row9_col0" class="data row9 col0" >0.229019</td>
#       <td id="T_804f1_row9_col1" class="data row9 col1" >13</td>
#     </tr>
#   </tbody>
# </table>

# %%
# we can fill the NaNs with a certain value if needed
# let's fill with -100 so we can see it clearly
left, right = d1.align(d2, join="outer", fill_value=-100)
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_727ac" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_727ac_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_727ac_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_727ac_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_727ac_row0_col0" class="data row0 col0" >0.436315</td>
#       <td id="T_727ac_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_727ac_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_727ac_row1_col0" class="data row1 col0" >0.107209</td>
#       <td id="T_727ac_row1_col1" class="data row1 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_727ac_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_727ac_row2_col0" class="data row2 col0" >0.306860</td>
#       <td id="T_727ac_row2_col1" class="data row2 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_727ac_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_727ac_row3_col0" class="data row3 col0" >0.556690</td>
#       <td id="T_727ac_row3_col1" class="data row3 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_727ac_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_727ac_row4_col0" class="data row4 col0" >0.236538</td>
#       <td id="T_727ac_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_727ac_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_727ac_row5_col0" class="data row5 col0" >0.507305</td>
#       <td id="T_727ac_row5_col1" class="data row5 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_727ac_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_727ac_row6_col0" class="data row6 col0" >0.869615</td>
#       <td id="T_727ac_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_727ac_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_727ac_row7_col0" class="data row7 col0" >0.963472</td>
#       <td id="T_727ac_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_727ac_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_727ac_row8_col0" class="data row8 col0" >0.955988</td>
#       <td id="T_727ac_row8_col1" class="data row8 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_727ac_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_727ac_row9_col0" class="data row9 col0" >0.752772</td>
#       <td id="T_727ac_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_727ac_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_727ac_row10_col0" class="data row10 col0" >-100.000000</td>
#       <td id="T_727ac_row10_col1" class="data row10 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_727ac_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_727ac_row11_col0" class="data row11 col0" >-100.000000</td>
#       <td id="T_727ac_row11_col1" class="data row11 col1" >-100</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_8d8e4" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d8e4_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_8d8e4_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d8e4_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_8d8e4_row0_col0" class="data row0 col0" >-100.000000</td>
#       <td id="T_8d8e4_row0_col1" class="data row0 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_8d8e4_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_8d8e4_row1_col0" class="data row1 col0" >-100.000000</td>
#       <td id="T_8d8e4_row1_col1" class="data row1 col1" >-100</td>
#     </tr>
#     <tr>
#       <th id="T_8d8e4_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_8d8e4_row2_col0" class="data row2 col0" >0.643014</td>
#       <td id="T_8d8e4_row2_col1" class="data row2 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_8d8e4_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_8d8e4_row3_col0" class="data row3 col0" >0.088042</td>
#       <td id="T_8d8e4_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_8d8e4_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_8d8e4_row4_col0" class="data row4 col0" >0.613500</td>
#       <td id="T_8d8e4_row4_col1" class="data row4 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_8d8e4_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_8d8e4_row5_col0" class="data row5 col0" >0.979507</td>
#       <td id="T_8d8e4_row5_col1" class="data row5 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_8d8e4_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_8d8e4_row6_col0" class="data row6 col0" >0.829249</td>
#       <td id="T_8d8e4_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_8d8e4_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_8d8e4_row7_col0" class="data row7 col0" >0.530647</td>
#       <td id="T_8d8e4_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_8d8e4_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_8d8e4_row8_col0" class="data row8 col0" >0.561214</td>
#       <td id="T_8d8e4_row8_col1" class="data row8 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_8d8e4_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_8d8e4_row9_col0" class="data row9 col0" >0.161999</td>
#       <td id="T_8d8e4_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_8d8e4_level0_row10" class="row_heading level0 row10" >2022-01-11 00:00:00</th>
#       <td id="T_8d8e4_row10_col0" class="data row10 col0" >0.861839</td>
#       <td id="T_8d8e4_row10_col1" class="data row10 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_8d8e4_level0_row11" class="row_heading level0 row11" >2022-01-12 00:00:00</th>
#       <td id="T_8d8e4_row11_col0" class="data row11 col0" >0.229019</td>
#       <td id="T_8d8e4_row11_col1" class="data row11 col1" >13</td>
#     </tr>
#   </tbody>
# </table>

# %%
# left join: left index is added to right, but not the other way
left, right = d1.align(d2, join="left")
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6fe0d" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6fe0d_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_6fe0d_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fe0d_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_6fe0d_row0_col0" class="data row0 col0" >0.436315</td>
#       <td id="T_6fe0d_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6fe0d_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_6fe0d_row1_col0" class="data row1 col0" >0.107209</td>
#       <td id="T_6fe0d_row1_col1" class="data row1 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_6fe0d_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_6fe0d_row2_col0" class="data row2 col0" >0.306860</td>
#       <td id="T_6fe0d_row2_col1" class="data row2 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_6fe0d_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_6fe0d_row3_col0" class="data row3 col0" >0.556690</td>
#       <td id="T_6fe0d_row3_col1" class="data row3 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_6fe0d_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_6fe0d_row4_col0" class="data row4 col0" >0.236538</td>
#       <td id="T_6fe0d_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6fe0d_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_6fe0d_row5_col0" class="data row5 col0" >0.507305</td>
#       <td id="T_6fe0d_row5_col1" class="data row5 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_6fe0d_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_6fe0d_row6_col0" class="data row6 col0" >0.869615</td>
#       <td id="T_6fe0d_row6_col1" class="data row6 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_6fe0d_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_6fe0d_row7_col0" class="data row7 col0" >0.963472</td>
#       <td id="T_6fe0d_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_6fe0d_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_6fe0d_row8_col0" class="data row8 col0" >0.955988</td>
#       <td id="T_6fe0d_row8_col1" class="data row8 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_6fe0d_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_6fe0d_row9_col0" class="data row9 col0" >0.752772</td>
#       <td id="T_6fe0d_row9_col1" class="data row9 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_6efda" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6efda_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_6efda_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6efda_level0_row0" class="row_heading level0 row0" >2022-01-01 00:00:00</th>
#       <td id="T_6efda_row0_col0" class="data row0 col0" >nan</td>
#       <td id="T_6efda_row0_col1" class="data row0 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6efda_level0_row1" class="row_heading level0 row1" >2022-01-02 00:00:00</th>
#       <td id="T_6efda_row1_col0" class="data row1 col0" >nan</td>
#       <td id="T_6efda_row1_col1" class="data row1 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_6efda_level0_row2" class="row_heading level0 row2" >2022-01-03 00:00:00</th>
#       <td id="T_6efda_row2_col0" class="data row2 col0" >0.643014</td>
#       <td id="T_6efda_row2_col1" class="data row2 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6efda_level0_row3" class="row_heading level0 row3" >2022-01-04 00:00:00</th>
#       <td id="T_6efda_row3_col0" class="data row3 col0" >0.088042</td>
#       <td id="T_6efda_row3_col1" class="data row3 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6efda_level0_row4" class="row_heading level0 row4" >2022-01-05 00:00:00</th>
#       <td id="T_6efda_row4_col0" class="data row4 col0" >0.613500</td>
#       <td id="T_6efda_row4_col1" class="data row4 col1" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6efda_level0_row5" class="row_heading level0 row5" >2022-01-06 00:00:00</th>
#       <td id="T_6efda_row5_col0" class="data row5 col0" >0.979507</td>
#       <td id="T_6efda_row5_col1" class="data row5 col1" >15.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6efda_level0_row6" class="row_heading level0 row6" >2022-01-07 00:00:00</th>
#       <td id="T_6efda_row6_col0" class="data row6 col0" >0.829249</td>
#       <td id="T_6efda_row6_col1" class="data row6 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6efda_level0_row7" class="row_heading level0 row7" >2022-01-08 00:00:00</th>
#       <td id="T_6efda_row7_col0" class="data row7 col0" >0.530647</td>
#       <td id="T_6efda_row7_col1" class="data row7 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6efda_level0_row8" class="row_heading level0 row8" >2022-01-09 00:00:00</th>
#       <td id="T_6efda_row8_col0" class="data row8 col0" >0.561214</td>
#       <td id="T_6efda_row8_col1" class="data row8 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6efda_level0_row9" class="row_heading level0 row9" >2022-01-10 00:00:00</th>
#       <td id="T_6efda_row9_col0" class="data row9 col0" >0.161999</td>
#       <td id="T_6efda_row9_col1" class="data row9 col1" >6.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# right join: right index is added to left, but not the other way
left, right = d1.align(d2, join="right")
render_df_side_by_side(left, right)
# Out:
# <style type="text/css">
# </style>
# <table id="T_76194" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76194_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_76194_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76194_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_76194_row0_col0" class="data row0 col0" >0.306860</td>
#       <td id="T_76194_row0_col1" class="data row0 col1" >14.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76194_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_76194_row1_col0" class="data row1 col0" >0.556690</td>
#       <td id="T_76194_row1_col1" class="data row1 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76194_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_76194_row2_col0" class="data row2 col0" >0.236538</td>
#       <td id="T_76194_row2_col1" class="data row2 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76194_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_76194_row3_col0" class="data row3 col0" >0.507305</td>
#       <td id="T_76194_row3_col1" class="data row3 col1" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76194_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_76194_row4_col0" class="data row4 col0" >0.869615</td>
#       <td id="T_76194_row4_col1" class="data row4 col1" >23.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76194_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_76194_row5_col0" class="data row5 col0" >0.963472</td>
#       <td id="T_76194_row5_col1" class="data row5 col1" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76194_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_76194_row6_col0" class="data row6 col0" >0.955988</td>
#       <td id="T_76194_row6_col1" class="data row6 col1" >18.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76194_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_76194_row7_col0" class="data row7 col0" >0.752772</td>
#       <td id="T_76194_row7_col1" class="data row7 col1" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_76194_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_76194_row8_col0" class="data row8 col0" >nan</td>
#       <td id="T_76194_row8_col1" class="data row8 col1" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_76194_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_76194_row9_col0" class="data row9 col0" >nan</td>
#       <td id="T_76194_row9_col1" class="data row9 col1" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ae8d9" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae8d9_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ae8d9_level0_col1" class="col_heading level0 col1" >B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae8d9_level0_row0" class="row_heading level0 row0" >2022-01-03 00:00:00</th>
#       <td id="T_ae8d9_row0_col0" class="data row0 col0" >0.643014</td>
#       <td id="T_ae8d9_row0_col1" class="data row0 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_ae8d9_level0_row1" class="row_heading level0 row1" >2022-01-04 00:00:00</th>
#       <td id="T_ae8d9_row1_col0" class="data row1 col0" >0.088042</td>
#       <td id="T_ae8d9_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ae8d9_level0_row2" class="row_heading level0 row2" >2022-01-05 00:00:00</th>
#       <td id="T_ae8d9_row2_col0" class="data row2 col0" >0.613500</td>
#       <td id="T_ae8d9_row2_col1" class="data row2 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_ae8d9_level0_row3" class="row_heading level0 row3" >2022-01-06 00:00:00</th>
#       <td id="T_ae8d9_row3_col0" class="data row3 col0" >0.979507</td>
#       <td id="T_ae8d9_row3_col1" class="data row3 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_ae8d9_level0_row4" class="row_heading level0 row4" >2022-01-07 00:00:00</th>
#       <td id="T_ae8d9_row4_col0" class="data row4 col0" >0.829249</td>
#       <td id="T_ae8d9_row4_col1" class="data row4 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_ae8d9_level0_row5" class="row_heading level0 row5" >2022-01-08 00:00:00</th>
#       <td id="T_ae8d9_row5_col0" class="data row5 col0" >0.530647</td>
#       <td id="T_ae8d9_row5_col1" class="data row5 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_ae8d9_level0_row6" class="row_heading level0 row6" >2022-01-09 00:00:00</th>
#       <td id="T_ae8d9_row6_col0" class="data row6 col0" >0.561214</td>
#       <td id="T_ae8d9_row6_col1" class="data row6 col1" >18</td>
#     </tr>
#     <tr>
#       <th id="T_ae8d9_level0_row7" class="row_heading level0 row7" >2022-01-10 00:00:00</th>
#       <td id="T_ae8d9_row7_col0" class="data row7 col0" >0.161999</td>
#       <td id="T_ae8d9_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_ae8d9_level0_row8" class="row_heading level0 row8" >2022-01-11 00:00:00</th>
#       <td id="T_ae8d9_row8_col0" class="data row8 col0" >0.861839</td>
#       <td id="T_ae8d9_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ae8d9_level0_row9" class="row_heading level0 row9" >2022-01-12 00:00:00</th>
#       <td id="T_ae8d9_row9_col0" class="data row9 col0" >0.229019</td>
#       <td id="T_ae8d9_row9_col1" class="data row9 col1" >13</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There's more to explore in align, and it can get confusing, so beginners be careful, take time and try to work out the result before you execute to build intuition.

# %% [markdown]
# # Operations on data

# %% [markdown]
# ## Stats
#
# Operations in general *exclude* missing data

# %%
# arithmetic mean, for each column (axis = 0)
df.mean()
# Out:
# A     0.180908
# B    -0.373763
# C     0.085587
# D     0.420536
# F    15.500000
# dtype: float64

# %%
# mean across a row (axis = 1)
df.mean(1)
# Out:
# 2022-06-19    1.829282
# 2022-06-20    2.487251
# 2022-06-21    2.967633
# 2022-06-22    3.346482
# 2022-06-23    2.689869
# 2022-06-24    3.132428
# 2022-06-25    3.483694
# 2022-06-26    3.678126
# 2022-06-27    3.478130
# 2022-06-28    4.533640
# Freq: D, dtype: float64

# %% [markdown]
# ## Apply

# %%
# apply custom lambdas
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.561938
# B    2.167914
# C    3.529942
# D    2.225933
# F    9.000000
# dtype: float64

# %%
df
# Out:
#                    A         B         C         D   F
# 2022-06-19  1.041341 -1.063632 -1.513852 -0.317446  11
# 2022-06-20  0.158545  0.584616 -1.219899  0.912992  12
# 2022-06-21  0.733003 -0.188384  2.016090 -0.722546  13
# 2022-06-22  1.536870  0.180747  0.121895  0.892899  14
# 2022-06-23 -0.051249 -1.583298  0.394773 -0.310881  15
# 2022-06-24  0.038414 -1.251971  0.670493  0.205204  16
# 2022-06-25 -1.025068  0.067278  0.962100  0.414161  17
# 2022-06-26 -0.545829 -0.908608  0.341681  1.503387  18
# 2022-06-27 -0.733098 -0.096156 -1.398009  0.617913  19
# 2022-06-28  0.656146  0.521780  0.480596  1.009676  20

# %%
# each subsequent value is a sum of all values before it in the respective column
cumsum_df = df.apply(np.cumsum)
render_df_side_by_side(df, cumsum_df, "OG Dataframe", "Cumulative Sum")
# Out:
# <style type="text/css">
# </style>
# <table id="T_ed387" style='display:inline'>
#   <caption>OG Dataframe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed387_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_ed387_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_ed387_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_ed387_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_ed387_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed387_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_ed387_row0_col0" class="data row0 col0" >1.041341</td>
#       <td id="T_ed387_row0_col1" class="data row0 col1" >-1.063632</td>
#       <td id="T_ed387_row0_col2" class="data row0 col2" >-1.513852</td>
#       <td id="T_ed387_row0_col3" class="data row0 col3" >-0.317446</td>
#       <td id="T_ed387_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_ed387_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_ed387_row1_col0" class="data row1 col0" >0.158545</td>
#       <td id="T_ed387_row1_col1" class="data row1 col1" >0.584616</td>
#       <td id="T_ed387_row1_col2" class="data row1 col2" >-1.219899</td>
#       <td id="T_ed387_row1_col3" class="data row1 col3" >0.912992</td>
#       <td id="T_ed387_row1_col4" class="data row1 col4" >12</td>
#     </tr>
#     <tr>
#       <th id="T_ed387_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_ed387_row2_col0" class="data row2 col0" >0.733003</td>
#       <td id="T_ed387_row2_col1" class="data row2 col1" >-0.188384</td>
#       <td id="T_ed387_row2_col2" class="data row2 col2" >2.016090</td>
#       <td id="T_ed387_row2_col3" class="data row2 col3" >-0.722546</td>
#       <td id="T_ed387_row2_col4" class="data row2 col4" >13</td>
#     </tr>
#     <tr>
#       <th id="T_ed387_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_ed387_row3_col0" class="data row3 col0" >1.536870</td>
#       <td id="T_ed387_row3_col1" class="data row3 col1" >0.180747</td>
#       <td id="T_ed387_row3_col2" class="data row3 col2" >0.121895</td>
#       <td id="T_ed387_row3_col3" class="data row3 col3" >0.892899</td>
#       <td id="T_ed387_row3_col4" class="data row3 col4" >14</td>
#     </tr>
#     <tr>
#       <th id="T_ed387_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_ed387_row4_col0" class="data row4 col0" >-0.051249</td>
#       <td id="T_ed387_row4_col1" class="data row4 col1" >-1.583298</td>
#       <td id="T_ed387_row4_col2" class="data row4 col2" >0.394773</td>
#       <td id="T_ed387_row4_col3" class="data row4 col3" >-0.310881</td>
#       <td id="T_ed387_row4_col4" class="data row4 col4" >15</td>
#     </tr>
#     <tr>
#       <th id="T_ed387_level0_row5" class="row_heading level0 row5" >2022-06-24 00:00:00</th>
#       <td id="T_ed387_row5_col0" class="data row5 col0" >0.038414</td>
#       <td id="T_ed387_row5_col1" class="data row5 col1" >-1.251971</td>
#       <td id="T_ed387_row5_col2" class="data row5 col2" >0.670493</td>
#       <td id="T_ed387_row5_col3" class="data row5 col3" >0.205204</td>
#       <td id="T_ed387_row5_col4" class="data row5 col4" >16</td>
#     </tr>
#     <tr>
#       <th id="T_ed387_level0_row6" class="row_heading level0 row6" >2022-06-25 00:00:00</th>
#       <td id="T_ed387_row6_col0" class="data row6 col0" >-1.025068</td>
#       <td id="T_ed387_row6_col1" class="data row6 col1" >0.067278</td>
#       <td id="T_ed387_row6_col2" class="data row6 col2" >0.962100</td>
#       <td id="T_ed387_row6_col3" class="data row6 col3" >0.414161</td>
#       <td id="T_ed387_row6_col4" class="data row6 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_ed387_level0_row7" class="row_heading level0 row7" >2022-06-26 00:00:00</th>
#       <td id="T_ed387_row7_col0" class="data row7 col0" >-0.545829</td>
#       <td id="T_ed387_row7_col1" class="data row7 col1" >-0.908608</td>
#       <td id="T_ed387_row7_col2" class="data row7 col2" >0.341681</td>
#       <td id="T_ed387_row7_col3" class="data row7 col3" >1.503387</td>
#       <td id="T_ed387_row7_col4" class="data row7 col4" >18</td>
#     </tr>
#     <tr>
#       <th id="T_ed387_level0_row8" class="row_heading level0 row8" >2022-06-27 00:00:00</th>
#       <td id="T_ed387_row8_col0" class="data row8 col0" >-0.733098</td>
#       <td id="T_ed387_row8_col1" class="data row8 col1" >-0.096156</td>
#       <td id="T_ed387_row8_col2" class="data row8 col2" >-1.398009</td>
#       <td id="T_ed387_row8_col3" class="data row8 col3" >0.617913</td>
#       <td id="T_ed387_row8_col4" class="data row8 col4" >19</td>
#     </tr>
#     <tr>
#       <th id="T_ed387_level0_row9" class="row_heading level0 row9" >2022-06-28 00:00:00</th>
#       <td id="T_ed387_row9_col0" class="data row9 col0" >0.656146</td>
#       <td id="T_ed387_row9_col1" class="data row9 col1" >0.521780</td>
#       <td id="T_ed387_row9_col2" class="data row9 col2" >0.480596</td>
#       <td id="T_ed387_row9_col3" class="data row9 col3" >1.009676</td>
#       <td id="T_ed387_row9_col4" class="data row9 col4" >20</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_a5bf2" style='display:inline'>
#   <caption>Cumulative Sum</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5bf2_level0_col0" class="col_heading level0 col0" >A</th>
#       <th id="T_a5bf2_level0_col1" class="col_heading level0 col1" >B</th>
#       <th id="T_a5bf2_level0_col2" class="col_heading level0 col2" >C</th>
#       <th id="T_a5bf2_level0_col3" class="col_heading level0 col3" >D</th>
#       <th id="T_a5bf2_level0_col4" class="col_heading level0 col4" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5bf2_level0_row0" class="row_heading level0 row0" >2022-06-19 00:00:00</th>
#       <td id="T_a5bf2_row0_col0" class="data row0 col0" >1.041341</td>
#       <td id="T_a5bf2_row0_col1" class="data row0 col1" >-1.063632</td>
#       <td id="T_a5bf2_row0_col2" class="data row0 col2" >-1.513852</td>
#       <td id="T_a5bf2_row0_col3" class="data row0 col3" >-0.317446</td>
#       <td id="T_a5bf2_row0_col4" class="data row0 col4" >11</td>
#     </tr>
#     <tr>
#       <th id="T_a5bf2_level0_row1" class="row_heading level0 row1" >2022-06-20 00:00:00</th>
#       <td id="T_a5bf2_row1_col0" class="data row1 col0" >1.199886</td>
#       <td id="T_a5bf2_row1_col1" class="data row1 col1" >-0.479016</td>
#       <td id="T_a5bf2_row1_col2" class="data row1 col2" >-2.733751</td>
#       <td id="T_a5bf2_row1_col3" class="data row1 col3" >0.595546</td>
#       <td id="T_a5bf2_row1_col4" class="data row1 col4" >23</td>
#     </tr>
#     <tr>
#       <th id="T_a5bf2_level0_row2" class="row_heading level0 row2" >2022-06-21 00:00:00</th>
#       <td id="T_a5bf2_row2_col0" class="data row2 col0" >1.932888</td>
#       <td id="T_a5bf2_row2_col1" class="data row2 col1" >-0.667400</td>
#       <td id="T_a5bf2_row2_col2" class="data row2 col2" >-0.717661</td>
#       <td id="T_a5bf2_row2_col3" class="data row2 col3" >-0.127000</td>
#       <td id="T_a5bf2_row2_col4" class="data row2 col4" >36</td>
#     </tr>
#     <tr>
#       <th id="T_a5bf2_level0_row3" class="row_heading level0 row3" >2022-06-22 00:00:00</th>
#       <td id="T_a5bf2_row3_col0" class="data row3 col0" >3.469759</td>
#       <td id="T_a5bf2_row3_col1" class="data row3 col1" >-0.486653</td>
#       <td id="T_a5bf2_row3_col2" class="data row3 col2" >-0.595766</td>
#       <td id="T_a5bf2_row3_col3" class="data row3 col3" >0.765899</td>
#       <td id="T_a5bf2_row3_col4" class="data row3 col4" >50</td>
#     </tr>
#     <tr>
#       <th id="T_a5bf2_level0_row4" class="row_heading level0 row4" >2022-06-23 00:00:00</th>
#       <td id="T_a5bf2_row4_col0" class="data row4 col0" >3.418510</td>
#       <td id="T_a5bf2_row4_col1" class="data row4 col1" >-2.069950</td>
#       <td id="T_a5bf2_row4_col2" class="data row4 col2" >-0.200993</td>
#       <td id="T_a5bf2

# %% [markdown]
# ## Histogramming
#
# Frequencies, 'nuff said
#
# ```value_counts()```

# %%
series1 = pd.Series(np.random.randint(0, 5, size=25))
series1.value_counts()
# Out:
# 4    7
# 2    7
# 1    4
# 3    4
# 0    3
# Name: count, dtype: int64

# %% [markdown]
# ## String Methods

# %%
# build a series
some_string = "SERIes and Index are EqUIppeD WITh A seT Of stRINg PROCESSING METHoDs In tHe ```sTR``` attrIBute THAT MakE IT eASy To oPerATE ON EACh ELEmeNt OF The aRrAY. NOtE thAt PAtTERN-maTching in ```sTR``` gENeralLY UsES reGUlAr eXpreSsiONs bY DEfault (aND In Some cases AlwayS uSEs tHeM)."
str_series = pd.Series(some_string.split())  # split splits on whitespace by default

# %%
# manipulating the case - lower, upper etc.
# also the length of each string, split, replace, yada yada...
# very important when cleaning data (column names may have stupid whitespace, bad case, spacing etc.)
low = str_series.str.lower()
up = str_series.str.upper()

low_up_df = pd.DataFrame(
    {
        "og": str_series,
        "length": str_series.str.len(),
        "low": low,
        "up": up,
        "split_low_on_i": low.str.split(
            "i", expand=False
        ),  # expand = True will break this usecase, try elsewhere
        "replace_a_with_star_in_low": low.str.replace(
            "a", "*", case=False, regex=True
        ),  # yeah, you can mess with regular expns
    }
)

low_up_df.tail(10)
# Out:
#              og  length          low           up  split_low_on_i  \
# 36  eXpreSsiONs      11  expressions  EXPRESSIONS  [express, ons]
# 37           bY       2           by           BY            [by]
# 38      DEfault       7      default      DEFAULT       [default]
# 39         (aND       4         (and         (AND          [(and]
# 40           In       2           in           IN           [, n]
# 41         Some       4         some         SOME          [some]
# 42        cases       5        cases        CASES         [cases]
# 43       AlwayS       6       always       ALWAYS        [always]
# 44         uSEs       4         uses         USES          [uses]
# 45       tHeM).       6       them).       THEM).        [them).]
#
#    replace_a_with_star_in_low
# 36                expressions
# 37                         by
# 38                    def*ult
# 39                       (*nd
# 40                         in
# 41                       some
# 42                      c*ses
# 43                     *lw*ys
# 44                       uses
# 45                     them).

# %% [markdown]
# See [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#text-string-methods) for more string operations.

# %% [markdown]
# # Merge
#
# Combine series and dataframes, use set logic for indexes and relational algebra for joins/merges

# %% [markdown]
# ## Concat
#
# Chill, we've done this before. The same join = inner/outer/left/right drill.

# %%
# let's make some more dataframes
concatDF = pd.DataFrame(
    np.random.randn(10, 4)
)  # 10 rows and 4 columns of random numbers
pieces = [concatDF[:3], concatDF[3:7], concatDF[7:]]
reconstructedDF = pd.concat(pieces)
display("broken DFs: ", pieces)
render_df_side_by_side(concatDF, reconstructedDF, "OG", "Concatenated")
# Out:
# 'broken DFs: '
# [          0         1         2         3
#  0  0.010169 -0.556350 -0.000621 -1.960402
#  1 -0.907764 -0.820216  1.468134 -0.448061
#  2 -0.234968 -0.079560 -1.616295 -1.948658,
#            0         1         2         3
#  3 -0.448538  0.032117 -0.302534 -0.829890
#  4  1.318813 -1.485388  0.218991  0.412727
#  5  0.519029 -0.247932  1.345721 -0.192892
#  6  0.234364 -1.553647  0.269463  1.377713,
#            0         1         2         3
#  7  2.072935 -0.489588  0.227147  0.704755
#  8  0.123132 -0.189635  0.434946  0.833079
#  9  0.904314  1.208618 -0.871353 -0.349971]
# <style type="text/css">
# </style>
# <table id="T_7fe0d" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fe0d_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_7fe0d_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_7fe0d_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_7fe0d_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fe0d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7fe0d_row0_col0" class="data row0 col0" >0.010169</td>
#       <td id="T_7fe0d_row0_col1" class="data row0 col1" >-0.556350</td>
#       <td id="T_7fe0d_row0_col2" class="data row0 col2" >-0.000621</td>
#       <td id="T_7fe0d_row0_col3" class="data row0 col3" >-1.960402</td>
#     </tr>
#     <tr>
#       <th id="T_7fe0d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7fe0d_row1_col0" class="data row1 col0" >-0.907764</td>
#       <td id="T_7fe0d_row1_col1" class="data row1 col1" >-0.820216</td>
#       <td id="T_7fe0d_row1_col2" class="data row1 col2" >1.468134</td>
#       <td id="T_7fe0d_row1_col3" class="data row1 col3" >-0.448061</td>
#     </tr>
#     <tr>
#       <th id="T_7fe0d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7fe0d_row2_col0" class="data row2 col0" >-0.234968</td>
#       <td id="T_7fe0d_row2_col1" class="data row2 col1" >-0.079560</td>
#       <td id="T_7fe0d_row2_col2" class="data row2 col2" >-1.616295</td>
#       <td id="T_7fe0d_row2_col3" class="data row2 col3" >-1.948658</td>
#     </tr>
#     <tr>
#       <th id="T_7fe0d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7fe0d_row3_col0" class="data row3 col0" >-0.448538</td>
#       <td id="T_7fe0d_row3_col1" class="data row3 col1" >0.032117</td>
#       <td id="T_7fe0d_row3_col2" class="data row3 col2" >-0.302534</td>
#       <td id="T_7fe0d_row3_col3" class="data row3 col3" >-0.829890</td>
#     </tr>
#     <tr>
#       <th id="T_7fe0d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7fe0d_row4_col0" class="data row4 col0" >1.318813</td>
#       <td id="T_7fe0d_row4_col1" class="data row4 col1" >-1.485388</td>
#       <td id="T_7fe0d_row4_col2" class="data row4 col2" >0.218991</td>
#       <td id="T_7fe0d_row4_col3" class="data row4 col3" >0.412727</td>
#     </tr>
#     <tr>
#       <th id="T_7fe0d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7fe0d_row5_col0" class="data row5 col0" >0.519029</td>
#       <td id="T_7fe0d_row5_col1" class="data row5 col1" >-0.247932</td>
#       <td id="T_7fe0d_row5_col2" class="data row5 col2" >1.345721</td>
#       <td id="T_7fe0d_row5_col3" class="data row5 col3" >-0.192892</td>
#     </tr>
#     <tr>
#       <th id="T_7fe0d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7fe0d_row6_col0" class="data row6 col0" >0.234364</td>
#       <td id="T_7fe0d_row6_col1" class="data row6 col1" >-1.553647</td>
#       <td id="T_7fe0d_row6_col2" class="data row6 col2" >0.269463</td>
#       <td id="T_7fe0d_row6_col3" class="data row6 col3" >1.377713</td>
#     </tr>
#     <tr>
#       <th id="T_7fe0d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7fe0d_row7_col0" class="data row7 col0" >2.072935</td>
#       <td id="T_7fe0d_row7_col1" class="data row7 col1" >-0.489588</td>
#       <td id="T_7fe0d_row7_col2" class="data row7 col2" >0.227147</td>
#       <td id="T_7fe0d_row7_col3" class="data row7 col3" >0.704755</td>
#     </tr>
#     <tr>
#       <th id="T_7fe0d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7fe0d_row8_col0" class="data row8 col0" >0.123132</td>
#       <td id="T_7fe0d_row8_col1" class="data row8 col1" >-0.189635</td>
#       <td id="T_7fe0d_row8_col2" class="data row8 col2" >0.434946</td>
#       <td id="T_7fe0d_row8_col3" class="data row8 col3" >0.833079</td>
#     </tr>
#     <tr>
#       <th id="T_7fe0d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7fe0d_row9_col0" class="data row9 col0" >0.904314</td>
#       <td id="T_7fe0d_row9_col1" class="data row9 col1" >1.208618</td>
#       <td id="T_7fe0d_row9_col2" class="data row9 col2" >-0.871353</td>
#       <td id="T_7fe0d_row9_col3" class="data row9 col3" >-0.349971</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_cb9fa" style='display:inline'>
#   <caption>Concatenated</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb9fa_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_cb9fa_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_cb9fa_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_cb9fa_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb9fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb9fa_row0_col0" class="data row0 col0" >0.010169</td>
#       <td id="T_cb9fa_row0_col1" class="data row0 col1" >-0.556350</td>
#       <td id="T_cb9fa_row0_col2" class="data row0 col2" >-0.000621</td>
#       <td id="T_cb9fa_row0_col3" class="data row0 col3" >-1.960402</td>
#     </tr>
#     <tr>
#       <th id="T_cb9fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb9fa_row1_col0" class="data row1 col0" >-0.907764</td>
#       <td id="T_cb9fa_row1_col1" class="data row1 col1" >-0.820216</td>
#       <td id="T_cb9fa_row1_col2" class="data row1 col2" >1.468134</td>
#       <td id="T_cb9fa_row1_col3" class="data row1 col3" >-0.448061</td>
#     </tr>
#     <tr>
#       <th id="T_cb9fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb9fa_row2_col0" class="data row2 col0" >-0.234968</td>
#       <td id="T_cb9fa_row2_col1" class="data row2 col1" >-0.079560</td>
#       <td id="T_cb9fa_row2_col2" class="data row2 col2" >-1.616295</td>
#       <td id="T_cb9fa_row2_col3" class="data row2 col3" >-1.948658</td>
#     </tr>
#     <tr>
#       <th id="T_cb9fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb9fa_row3_col0" class="data row3 col0" >-0.448538</td>
#       <td id="T_cb9fa_row3_col1" class="data row3 col1" >0.032117</td>
#       <td id="T_cb9fa_row3_col2" class="data row3 col2" >-0.302534</td>
#       <td id="T_cb9fa_row3_col3" class="data row3 col3" >-0.829890</td>
#     </tr>
#     <tr>
#       <th id="T_cb9fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cb9fa_row4_col0" class="data row4 col0" >1.318813</td>
#       <td id="T_cb9fa_row4_col1" class="data row4 col1" >-1.485388</td>
#       <td id="T_cb9fa_row4_col2" class="data row4 col2" >0.218991</td>
#       <td id="T_cb9fa_row4_col3" class="data row4 col3" >0.412727</td>
#     </tr>
#     <tr>
#       <th id="T_cb9fa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cb9fa_row5_col0" class="data row5 col0" >0.519029</td>
#       <td id="T_cb9fa_row5_col1" class="data row5 col1" >-0.247932</td>
#       <td id="T_cb9fa_row5_col2" class="data row5 col2" >1.345721</td>
#       <td id="T_cb9fa_row5_col3" class="data row5 col3" >-0.192892</td>
#     </tr>
#     <tr>
#       <th id="T_cb9fa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cb9fa_row6_col0" class="data row6 col0" >0.234364</td>
#       <td id="T_cb9fa_row6_col1" class="data row6 col1" >-1.553647</td>
#       <td id="T_cb9fa_row6_col2" class="data row6 col2" >0.269463</td>
#       <td id="T_cb9fa_row6_col3" class="data row6 col3" >1.377713</td>
#     </tr>
#     <tr>
#       <th id="T_cb9fa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cb9fa_row7_col0" class="data row7 col0" >2.072935</td>
#       <td id="T_cb9fa_row7_col1" class="data row7 col1" >-0.489588</td>
#       <td id="T_cb9fa_row7_col2" class="data row7 col2" >0.227147</td>
#       <td id="T_cb9fa_row7_col3" class="data row7 col3" >0.704755</td>
#     </tr>
#     <tr>
#       <th id="T_cb9fa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cb9fa_row8_col0" class="data row8 col

# %% [markdown]
# _From the [page](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html#concat)_:
# Adding a column to a DataFrame is relatively fast. However, adding a row requires a copy, and may be expensive. We recommend passing a pre-built list of records to the DataFrame constructor instead of building a DataFrame by iteratively appending records to it.

# %% [markdown]
# ## Join
# SQL style merges.

# %%
# two data frames
sl = pd.Series(np.random.randint(10, size=6))
sr = sl.shift(2).fillna(0).astype(int)
left = pd.DataFrame({"key": list("ABCDEF"), "lval": sl})

right = pd.DataFrame({"key": list("ABBCDE"), "rval": sr})

# %%
render_df_side_by_side(left, right, "left", "right")
# Out:
# <style type="text/css">
# </style>
# <table id="T_abca3" style='display:inline'>
#   <caption>left</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abca3_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_abca3_level0_col1" class="col_heading level0 col1" >lval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abca3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_abca3_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_abca3_row0_col1" class="data row0 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_abca3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_abca3_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_abca3_row1_col1" class="data row1 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_abca3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_abca3_row2_col0" class="data row2 col0" >C</td>
#       <td id="T_abca3_row2_col1" class="data row2 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_abca3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_abca3_row3_col0" class="data row3 col0" >D</td>
#       <td id="T_abca3_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_abca3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_abca3_row4_col0" class="data row4 col0" >E</td>
#       <td id="T_abca3_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_abca3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_abca3_row5_col0" class="data row5 col0" >F</td>
#       <td id="T_abca3_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_f3472" style='display:inline'>
#   <caption>right</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3472_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_f3472_level0_col1" class="col_heading level0 col1" >rval</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3472_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3472_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_f3472_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f3472_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f3472_row1_col0" class="data row1 col0" >B</td>
#       <td id="T_f3472_row1_col1" class="data row1 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f3472_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f3472_row2_col0" class="data row2 col0" >B</td>
#       <td id="T_f3472_row2_col1" class="data row2 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f3472_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f3472_row3_col0" class="data row3 col0" >C</td>
#       <td id="T_f3472_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f3472_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f3472_row4_col0" class="data row4 col0" >D</td>
#       <td id="T_f3472_row4_col1" class="data row4 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_f3472_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f3472_row5_col0" class="data row5 col0" >E</td>
#       <td id="T_f3472_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#   </tbody>
# </table>

# %%
result = pd.merge(left, right, on="key")
result
# Out:
#   key  lval  rval
# 0   A     9     0
# 1   B     9     0
# 2   B     9     9
# 3   C     4     9
# 4   D     8     4
# 5   E     3     8

# %% [markdown]
# # Grouping

# %% [markdown]
# "Group By" really means one or more of the following happening:
# 1. **Split**: data is broken into groups based on some criteria
# 2. **Apply**: a data operation is executed on each of those groups
# 3. **Combine**: the results are combined back into a data structure

# %%
grp_df = pd.DataFrame(
    {
        "colA": list("AABCAABDAA"),
        "colB": list("1234567890"),
        "colC": np.random.randn(10),
        "colD": np.random.randn(10),
    }
)
grp_df
# Out:
#   colA colB      colC      colD
# 0    A    1  1.369083  0.207532
# 1    A    2 -0.184994  0.312400
# 2    B    3  0.377128 -1.747016
# 3    C    4  0.223174  0.339125
# 4    A    5  0.264843  1.136784
# 5    A    6 -1.093774 -0.506168
# 6    B    7 -0.496699 -0.959583
# 7    D    8 -0.483261  0.012860
# 8    A    9 -0.935374  0.227009
# 9    A    0 -0.235600 -1.649197

# %%
# a DataFrameGroupBy object object
grpby = grp_df.groupby("colA")

# list all the groups found
g = grpby.groups
g
# Out:
# {'A': [0, 1, 4, 5, 8, 9], 'B': [2, 6], 'C': [3], 'D': [7]}

# %%
# to create a dataframe from the group use something like
grpby.get_group("A")
# Out:
#   colA colB      colC      colD
# 0    A    1  1.369083  0.207532
# 1    A    2 -0.184994  0.312400
# 4    A    5  0.264843  1.136784
# 5    A    6 -1.093774 -0.506168
# 8    A    9 -0.935374  0.227009
# 9    A    0 -0.235600 -1.649197

# %% [markdown]
# ### Find all the groups

# %%
# but we may not know all the groups in the dataframe.
# so got to find a way to list all groups as dataframes.
#
# some basic python helps create a list of groupby names
grpby_labels_list = [*g.keys()]  # using the unpacking operator *
# alternatively
# grpby_labels_list = list(g.keys())
grpby_labels_list
# Out:
# ['A', 'B', 'C', 'D']

# %%
# create a dict where the group label is the key and the group dataframe is the value
grps = {lbl: grpby.get_group(lbl) for lbl in grpby_labels_list}

# now use the dict to access individual dataframes created out of the groupby operation
grps["B"]

# question: can we create a dataframe of dataframes?
# Out:
#   colA colB      colC      colD
# 2    B    3  0.377128 -1.747016
# 6    B    7 -0.496699 -0.959583

# %%
# You can see the datatype of the value is a pandas dataframe
type(grps["A"])
# Out:
# pandas.core.frame.DataFrame

# %%
# make a function of it all...
def get_all_groups(df_grpby):
    return {lbl: df_grpby.get_group(lbl) for lbl in list(df_grpby.groups.keys())}

# %%
grps = get_all_groups(grp_df.groupby("colA"))
grps
# Out:
# {'A':   colA colB      colC      colD
#  0    A    1  1.369083  0.207532
#  1    A    2 -0.184994  0.312400
#  4    A    5  0.264843  1.136784
#  5    A    6 -1.093774 -0.506168
#  8    A    9 -0.935374  0.227009
#  9    A    0 -0.235600 -1.649197,
#  'B':   colA colB      colC      colD
#  2    B    3  0.377128 -1.747016
#  6    B    7 -0.496699 -0.959583,
#  'C':   colA colB      colC      colD
#  3    C    4  0.223174  0.339125,
#  'D':   colA colB      colC     colD
#  7    D    8 -0.483261  0.01286}

# %%
# get a sum of values from each group
grp_df.groupby("colA").sum()
# Out:
#         colB      colC      colD
# colA
# A     125690 -0.815816 -0.271640
# B         37 -0.119571 -2.706599
# C          4  0.223174  0.339125
# D          8 -0.483261  0.012860

# %%
# let's add one more column to the dataframe
# we can try grouping on two columns
grp_df["colE"] = list("1231231231")
grp_df
# Out:
#   colA colB      colC      colD colE
# 0    A    1  1.369083  0.207532    1
# 1    A    2 -0.184994  0.312400    2
# 2    B    3  0.377128 -1.747016    3
# 3    C    4  0.223174  0.339125    1
# 4    A    5  0.264843  1.136784    2
# 5    A    6 -1.093774 -0.506168    3
# 6    B    7 -0.496699 -0.959583    1
# 7    D    8 -0.483261  0.012860    2
# 8    A    9 -0.935374  0.227009    3
# 9    A    0 -0.235600 -1.649197    1

# %%
g2 = grp_df.groupby(["colA", "colE"])
grps2 = get_all_groups(g2)
grps2
# Out:
# {('A',
#   '1'):   colA colB      colC      colD colE
#  0    A    1  1.369083  0.207532    1
#  9    A    0 -0.235600 -1.649197    1,
#  ('A',
#   '2'):   colA colB      colC      colD colE
#  1    A    2 -0.184994  0.312400    2
#  4    A    5  0.264843  1.136784    2,
#  ('A',
#   '3'):   colA colB      colC      colD colE
#  5    A    6 -1.093774 -0.506168    3
#  8    A    9 -0.935374  0.227009    3,
#  ('B',
#   '1'):   colA colB      colC      colD colE
#  6    B    7 -0.496699 -0.959583    1,
#  ('B',
#   '3'):   colA colB      colC      colD colE
#  2    B    3  0.377128 -1.747016    3,
#  ('C',
#   '1'):   colA colB      colC      colD colE
#  3    C    4  0.223174  0.339125    1,
#  ('D',
#   '2'):   colA colB      colC     colD colE
#  7    D    8 -0.483261  0.01286    2}

# %%
render_df_side_by_side(grps2[("A", "1")], grps2[("A", "2")], "A,1", "A,2")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c2f99" style='display:inline'>
#   <caption>A,1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2f99_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_c2f99_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_c2f99_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_c2f99_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_c2f99_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2f99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c2f99_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_c2f99_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_c2f99_row0_col2" class="data row0 col2" >1.369083</td>
#       <td id="T_c2f99_row0_col3" class="data row0 col3" >0.207532</td>
#       <td id="T_c2f99_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c2f99_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_c2f99_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_c2f99_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_c2f99_row1_col2" class="data row1 col2" >-0.235600</td>
#       <td id="T_c2f99_row1_col3" class="data row1 col3" >-1.649197</td>
#       <td id="T_c2f99_row1_col4" class="data row1 col4" >1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_c9517" style='display:inline'>
#   <caption>A,2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9517_level0_col0" class="col_heading level0 col0" >colA</th>
#       <th id="T_c9517_level0_col1" class="col_heading level0 col1" >colB</th>
#       <th id="T_c9517_level0_col2" class="col_heading level0 col2" >colC</th>
#       <th id="T_c9517_level0_col3" class="col_heading level0 col3" >colD</th>
#       <th id="T_c9517_level0_col4" class="col_heading level0 col4" >colE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9517_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_c9517_row0_col0" class="data row0 col0" >A</td>
#       <td id="T_c9517_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_c9517_row0_col2" class="data row0 col2" >-0.184994</td>
#       <td id="T_c9517_row0_col3" class="data row0 col3" >0.312400</td>
#       <td id="T_c9517_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c9517_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_c9517_row1_col0" class="data row1 col0" >A</td>
#       <td id="T_c9517_row1_col1" class="data row1 col1" >5</td>
#       <td id="T_c9517_row1_col2" class="data row1 col2" >0.264843</td>
#       <td id="T_c9517_row1_col3" class="data row1 col3" >1.136784</td>
#       <td id="T_c9517_row1_col4" class="data row1 col4" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Reshaping
#
# Stacking and Pivot Tables.
# This really warrants more practice, at least go through [the page](https://pandas.pydata.org/pandas-docs/stable/user_guide/reshaping.html#)

# %% [markdown]
# ## Stacking

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)

# %% [markdown]
# If the syntax [*expression](https://docs.python.org/dev/reference/expressions.html#calls) appears in the function call, expression must evaluate to an iterable. Elements from these iterables are treated as if they were additional positional arguments.
#
# ...although the *expression syntax may appear after explicit keyword arguments, it is processed before the keyword arguments (and any **expression arguments)

# %%
# starred expressions...
def f(a, b):
    print(a, " ", b)


f(
    b=1, *(2,)
)  # works, the tuple (iterable) is expanded, 2 is assigned to a, then b fills the next argument slot
# f (a=1, *(2,)) # FAILS, multiple values for argument 'a'
# Out:
# 2   1

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
stack_idx = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])

# %%
stack_df = pd.DataFrame(np.random.randn(8, 2), index=stack_idx, columns=["a", "b"])
stack_df
# Out:
#                      a         b
# first second
# bar   one    -1.620791  1.002835
#       two    -1.205341 -0.476586
# baz   one    -1.576837  0.074313
#       two     0.345155  1.187004
# foo   one     0.944614 -2.244044
#       two    -0.201253  1.270270
# qux   one     2.392296 -0.089860
#       two    -0.543244  2.259622

# %%
# stack really just combines the columns
stacked = stack_df.stack()
stacked
# Out:
# first  second
# bar    one     a   -1.620791
#                b    1.002835
#        two     a   -1.205341
#                b   -0.476586
# baz    one     a   -1.576837
#                b    0.074313
#        two     a    0.345155
#                b    1.187004
# foo    one     a    0.944614
#                b   -2.244044
#        two     a   -0.201253
#                b    1.270270
# qux    one     a    2.392296
#                b   -0.089860
#        two     a   -0.543244
#                b    2.259622
# dtype: float64

# %%
# unstacked brings back the two columns
# by default unstacks the last level
unstacked = stacked.unstack()
unstacked
# Out:
#                      a         b
# first second
# bar   one    -1.620791  1.002835
#       two    -1.205341 -0.476586
# baz   one    -1.576837  0.074313
#       two     0.345155  1.187004
# foo   one     0.944614 -2.244044
#       two    -0.201253  1.270270
# qux   one     2.392296 -0.089860
#       two    -0.543244  2.259622

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   a -1.620791 -1.205341
#       b  1.002835 -0.476586
# baz   a -1.576837  0.345155
#       b  0.074313  1.187004
# foo   a  0.944614 -0.201253
#       b -2.244044  1.270270
# qux   a  2.392296 -0.543244
#       b -0.089860  2.259622

# %%
stacked.unstack(0)
# Out:
# first          bar       baz       foo       qux
# second
# one    a -1.620791 -1.576837  0.944614  2.392296
#        b  1.002835  0.074313 -2.244044 -0.089860
# two    a -1.205341  0.345155 -0.201253 -0.543244
#        b -0.476586  1.187004  1.270270  2.259622

# %%
# you can basically pivot the columns and rows using a combination of stack() and unstack()
unstacked.unstack()
# Out:
#                a                   b
# second       one       two       one       two
# first
# bar    -1.620791 -1.205341  1.002835 -0.476586
# baz    -1.576837  0.345155  0.074313  1.187004
# foo     0.944614 -0.201253 -2.244044  1.270270
# qux     2.392296 -0.543244 -0.089860  2.259622

# %% [markdown]
# ## Pivot Tables

# %%
# we're now just using data created in the pandas documentation - just cause, time.
pivot_tables_df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)
pivot_tables_df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.404403  0.892837
# 1     one  B  foo -2.060640 -1.274157
# 2     two  C  foo  0.045220 -0.754610
# 3   three  A  bar  0.562695  1.588572
# 4     one  B  bar -1.653785 -1.263915
# 5     one  C  bar -0.323289 -0.101124
# 6     two  A  foo -0.459261 -1.141485
# 7   three  B  foo  0.427347  1.773260
# 8     one  C  foo  0.294265  0.484364
# 9     one  A  bar  0.022047 -0.974314
# 10    two  B  bar -0.161763 -0.511932
# 11  three  C  bar -0.690502  0.807688

# %%
# simple pivot tables - data, values to aggregate, index, columns to pivot along
pd.pivot_table(pivot_tables_df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A  0.022047 -0.404403
#       B -1.653785 -2.060640
#       C -0.323289  0.294265
# three A  0.562695       NaN
#       B       NaN  0.427347
#       C -0.690502       NaN
# two   A       NaN -0.459261
#       B -0.161763       NaN
#       C       NaN  0.045220

# %%
# more'n one columns of values
# mark all NaN as zero (0)
pd.pivot_table(
    pivot_tables_df, values=["D", "E"], index=["A", "B"], columns=["C"]
).fillna(0)
# Out:
#                 D                   E
# C             bar       foo       bar       foo
# A     B
# one   A  0.022047 -0.404403 -0.974314  0.892837
#       B -1.653785 -2.060640 -1.263915 -1.274157
#       C -0.323289  0.294265 -0.101124  0.484364
# three A  0.562695  0.000000  1.588572  0.000000
#       B  0.000000  0.427347  0.000000  1.773260
#       C -0.690502  0.000000  0.807688  0.000000
# two   A  0.000000 -0.459261  0.000000 -1.141485
#       B -0.161763  0.000000 -0.511932  0.000000
#       C  0.000000  0.045220  0.000000 -0.754610

# %% [markdown]
# # Time Series

# %% [markdown]
# ## Resample
# We may need to resample data to a different time-frequency.
# Like get data every second and resample to data every 5 minutes and so on...

# %%
rng = pd.date_range("01/01/2022", periods=1000, freq="S")

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample("5min").sum()
# Out:
# 2022-01-01 00:00:00    69223
# 2022-01-01 00:05:00    74972
# 2022-01-01 00:10:00    72784
# 2022-01-01 00:15:00    25986
# Freq: 5T, dtype: int64

# %% [markdown]
# read up on [date offset strings](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#dateoffset-objects) like '5min' etc.

# %% [markdown]
# ## Timezones

# %%
# timezone representation
rng2 = pd.date_range("01/01/2022", periods=500, freq="D")
ts2 = pd.Series(np.random.randint(0, 365, len(rng2)), index=rng2)
ts2_utc = ts2.tz_localize("UTC")

# %%
# convert to US/Eastern
ts2_utc.tz_convert("US/Eastern")
# Out:
# 2021-12-31 19:00:00-05:00    112
# 2022-01-01 19:00:00-05:00     65
# 2022-01-02 19:00:00-05:00    193
# 2022-01-03 19:00:00-05:00    336
# 2022-01-04 19:00:00-05:00    165
#                             ...
# 2023-05-10 20:00:00-04:00     59
# 2023-05-11 20:00:00-04:00     90
# 2023-05-12 20:00:00-04:00    268
# 2023-05-13 20:00:00-04:00     10
# 2023-05-14 20:00:00-04:00    193
# Freq: D, Length: 500, dtype: int64

# %% [markdown]
# ## Time span representations
#
# Converting between periods and timestamps.
#
# Period is a _timespan_ - span of time between two timestamps.

# %%
# month - end of each
rng3 = pd.date_range("01/01/2022", periods=12, freq="M")
rng3
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
ts3 = pd.Series(np.random.randn(len(rng3)), index=rng3)
ts3
# Out:
# 2022-01-31    0.283536
# 2022-02-28    1.390939
# 2022-03-31    0.040793
# 2022-04-30   -0.599574
# 2022-05-31   -0.247930
# 2022-06-30   -1.371522
# 2022-07-31   -0.714814
# 2022-08-31   -0.865276
# 2022-09-30   -0.880990
# 2022-10-31   -0.057540
# 2022-11-30   -0.439640
# 2022-12-31    0.553880
# Freq: M, dtype: float64

# %%
ps = ts3.to_period()
ps
# Out:
# 2022-01    0.283536
# 2022-02    1.390939
# 2022-03    0.040793
# 2022-04   -0.599574
# 2022-05   -0.247930
# 2022-06   -1.371522
# 2022-07   -0.714814
# 2022-08   -0.865276
# 2022-09   -0.880990
# 2022-10   -0.057540
# 2022-11   -0.439640
# 2022-12    0.553880
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2022-01-01    0.283536
# 2022-02-01    1.390939
# 2022-03-01    0.040793
# 2022-04-01   -0.599574
# 2022-05-01   -0.247930
# 2022-06-01   -1.371522
# 2022-07-01   -0.714814
# 2022-08-01   -0.865276
# 2022-09-01   -0.880990
# 2022-10-01   -0.057540
# 2022-11-01   -0.439640
# 2022-12-01    0.553880
# Freq: MS, dtype: float64

# %% [markdown]
# A more complex use-case:
# convert a _quarterly frequency_ with _year ending in November_ to _9am_ of _the end of the month_ _following_ the _quarter end_

# %%
prng = pd.period_range("1990Q1", "2022Q4", freq="Q-NOV")
type(prng)
# Out:
# pandas.core.indexes.period.PeriodIndex

# %%
ts4 = pd.Series(np.random.randn(len(prng)), index=prng)
ts4.head()
# Out:
# 1990Q1   -2.916464
# 1990Q2   -0.056301
# 1990Q3    1.675062
# 1990Q4   -1.128001
# 1991Q1    1.588378
# Freq: Q-NOV, dtype: float64

# %%
ts4.index = (prng.asfreq("M", "e") + 1).asfreq("H", "s") + 9
ts4.head()
# Out:
# 1990-03-01 09:00   -2.916464
# 1990-06-01 09:00   -0.056301
# 1990-09-01 09:00    1.675062
# 1990-12-01 09:00   -1.128001
# 1991-03-01 09:00    1.588378
# Freq: H, dtype: float64

# %% [markdown]
# # Categoricals
#
# [This page](https://pandas.pydata.org/pandas-docs/stable/user_guide/categorical.html#categorical-data).
#
# ##### Note: With v2.0+ some of these are breaking - so this sections needs an update.
#
# See [this issue on GitHub](https://github.com/pandas-dev/pandas/issues/52593)
#
# For e.g., gender, social class, blood type, country affiliation, observation time or rating via Likert scales.
#
# Categorical data. Categories allow (usually) fixed number of possible values. Categorical data may have some order, but not support numerical operations (for e.g., 'strongly agree', 'agree', 'disagree', 'strongly disagree').

# %%
cat_df = pd.DataFrame({"id": list("123456"), "raw_grade": list("abbaae")})
cat_df
# Out:
#   id raw_grade
# 0  1         a
# 1  2         b
# 2  3         b
# 3  4         a
# 4  5         a
# 5  6         e

# %%
# convert the raw_grade col to categories
cat_df["grade"] = cat_df["raw_grade"].astype("category")
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
cat_df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
# this breaks with v2.0+
# [TODO] Find a fix

# can give more meaningful names here
# direct assignment to Series.cat.categories()
# cat_df["grade"].cat.categories = ["very good", "meh", "very bad"]
# cat_df["grade"]

# %%
cat_df
# Out:
#   id raw_grade grade
# 0  1         a     a
# 1  2         b     b
# 2  3         b     b
# 3  4         a     a
# 4  5         a     a
# 5  6         e     e

# %%
# list of categories
list(cat_df["grade"].cat.categories)

# categorical.CategoricalAccessor encapsulates all changes to categoricals
# for e.g., set_categories or remove_categories
# dir(cat_df['grade'].cat)
# Out:
# ['a', 'b', 'e']

# %%
# add more categories
cat_df["grade"] = cat_df["grade"].cat.set_categories(
    ["very bad", "bad", "meh", "good", "very good"]
)
# new list of categories
list(cat_df["grade"].cat.categories)
# Out:
# ['very bad', 'bad', 'meh', 'good', 'very good']

# %%
# now when we can sort the dataframe in order of categories (not lexical)
sorted_cat_df = cat_df.sort_values(by="grade")
render_df_side_by_side(cat_df, sorted_cat_df, "OG", "Sorted")
# Out:
# <style type="text/css">
# </style>
# <table id="T_629f5" style='display:inline'>
#   <caption>OG</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_629f5_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_629f5_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_629f5_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_629f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_629f5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_629f5_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_629f5_row0_col2" class="data row0 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_629f5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_629f5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_629f5_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_629f5_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_629f5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_629f5_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_629f5_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_629f5_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_629f5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_629f5_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_629f5_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_629f5_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_629f5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_629f5_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_629f5_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_629f5_row4_col2" class="data row4 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_629f5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_629f5_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_629f5_row5_col1" class="data row5 col1" >e</td>
#       <td id="T_629f5_row5_col2" class="data row5 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_8b412" style='display:inline'>
#   <caption>Sorted</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b412_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_8b412_level0_col1" class="col_heading level0 col1" >raw_grade</th>
#       <th id="T_8b412_level0_col2" class="col_heading level0 col2" >grade</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b412_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b412_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_8b412_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_8b412_row0_col2" class="data row0 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8b412_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8b412_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_8b412_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_8b412_row1_col2" class="data row1 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8b412_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8b412_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_8b412_row2_col1" class="data row2 col1" >b</td>
#       <td id="T_8b412_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8b412_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8b412_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_8b412_row3_col1" class="data row3 col1" >a</td>
#       <td id="T_8b412_row3_col2" class="data row3 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8b412_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8b412_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_8b412_row4_col1" class="data row4 col1" >a</td>
#       <td id="T_8b412_row4_col2" class="data row4 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_8b412_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8b412_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_8b412_row5_col1" class="data row5 col1" >e</td>
#       <td id="T_8b412_row5_col2" class="data row5 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
# grouping
# cat_grp = cat_df.groupby("grade")
# cat_grp.get_group("very good")

# %%
# count elements
# cat_grp.size()
